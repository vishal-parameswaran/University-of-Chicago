# %% [markdown]
# ## Natural Language Understanding
# https://natural-language-understanding-demo.mybluemix.net/
# https://github.com/watson-developer-cloud/python-sdk/blob/master/examples/natural_language_understanding_v1.py
#
# ### Run on GCC
# Everyone should be able to get access to "free tier" of IBM cloud, offer includes IBM Cloud as well as Watson services

# %%
import sys
import os
import json
import re
import pandas as pd

# %%
# !pip install ibm_watson

# %%
import ibm_watson
from ibm_watson import NaturalLanguageUnderstandingV1
from ibm_watson.natural_language_understanding_v1 import Features, EntitiesOptions, \
    KeywordsOptions, CategoriesOptions, ConceptsOptions, EmotionOptions, SentimentOptions, \
    RelationsOptions, SemanticRolesOptions
    
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

# %%
authenticator = IAMAuthenticator('your_credentials')
natural_language_understanding = NaturalLanguageUnderstandingV1(
    version='2019-07-12',
    authenticator=authenticator
)

natural_language_understanding.set_service_url('https://gateway.watsonplatform.net/natural-language-understanding/api')

# %% [markdown]
# #### Copy files to local FS from GCP bucket

# %%
# !mkdir -p /home/jupyter/data/tweets

# %%
# !gsutil -m cp -n 'gs://msca-bdp-data-open/tweets/jeep_new.txt' '/home/jupyter/data/tweets/'

# %% [markdown]
# https://watson-api-explorer.mybluemix.net/apis/natural-language-understanding-v1

# %% [markdown]
# #### Concepts
#
# Identify general concepts that are referenced or alluded to in your content. Concepts that are detected typically have an associated link to a DBpedia resource.
#
# #### Entities
# Detect important people, places, geopolitical entities and other types of entities in your content. Entity detection recognizes consecutive coreferences of each entity. For example, analysis of the following text would count "Barack Obama" and "He" as the same entity:
# "Barack Obama was the 44th President of the United States. He took office in January 2009."
#
# #### Keywords
# Determine the most important keywords in your content. Keyword phrases are organized by relevance in the results.
#
# #### Categories
# Categorize your content into a hierarchical 5-level taxonomy. For example, "Leonardo DiCaprio won an Oscar" returns "/art and entertainment/movies and tv/movies" as the most confident classification.
#
# #### Sentiment
# Determine whether your content conveys postive or negative sentiment. Sentiment information can be returned for detected entities, keywords, or user-specified target phrases found in the text.
#
# #### Emotion
# Detect anger, disgust, fear, joy, or sadness that is conveyed by your content. Emotion information can be returned for detected entities, keywords, or user-specified target phrases found in the text.
#
# #### Relations
# Recognize when two entities are related, and identify the type of relation. For example, you can identify an "awardedTo" relation between an award and its recipient.
#
# #### Semantic Roles
# Parse sentences into subject-action-object form, and identify entities and keywords that are subjects or objects of an action.

# %% [markdown]
# ## Analyzing text

# %% [raw]
# text='After overtaking BMW last year as the world’s largest luxury automaker, \
# Mercedes-Benz is turning its attention to a newer, untapped audience: \
# millennials seeking smaller cars as they progress through the stages of early adulthood.'

# %%
response = natural_language_understanding.analyze(
            language = "en", text = text,
            features = Features(
                        entities = EntitiesOptions(sentiment = True, emotion = True),
                        #keywords = KeywordsOptions(sentiment = True, emotion = True),
                        #concepts = ConceptsOptions(limit = 50),
                        #relations = RelationsOptions(),
                        #sentiment = SentimentOptions(),
                        #semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        #emotion = EmotionOptions(),
                        #categories = CategoriesOptions()
            )).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 230,
#     "features": 1
#   },
#   "language": "en",
#   "entities": [
#     {
#       "type": "Company",
#       "text": "BMW",
#       "sentiment": {
#         "score": 0.938528,
#         "label": "positive"
#       },
#       "relevance": 0.958279,
#       "emotion": {
#         "sadness": 0.19455,
#         "joy": 0.595719,
#         "fear": 0.069535,
#         "disgust": 0.050423,
#         "anger": 0.046226
#       },
#       "disambiguation": {
#         "subtype": [
#           "Organization",
#           "Engine",
#           "AutomobileCompany",
#           "AwardWinner"
#         ],
#         "name": "BMW",
#         "dbpedia_resource": "http://dbpedia.org/resource/BMW"
#       },
#       "count": 1,
#       "confidence": 0.997132
#     },
#     {
#       "type": "Company",
#       "text": "Benz",
#       "sentiment": {
#         "score": 0.938528,
#         "label": "positive"
#       },
#       "relevance": 0.854734,
#       "emotion": {
#         "sadness": 0.19455,
#         "joy": 0.595719,
#         "fear": 0.069535,
#         "disgust": 0.050423,
#         "anger": 0.046226
#       },
#       "count": 1,
#       "confidence": 0.921751
#     },
#     {
#       "type": "Company",
#       "text": "Mercedes",
#       "sentiment": {
#         "score": 0.938528,
#         "label": "positive"
#       },
#       "relevance": 0.810889,
#       "emotion": {
#         "sadness": 0.19455,
#         "joy": 0.595719,
#         "fear": 0.069535,
#         "disgust": 0.050423,
#         "anger": 0.046226
#       },
#       "disambiguation": {
#         "subtype": [
#           "Organization",
#           "AutomotiveDesigner",
#           "AwardWinner"
#         ],
#         "name": "Mercedes-Benz",
#         "dbpedia_resource": "http://dbpedia.org/resource/Mercedes-Benz"
#       },
#       "count": 1,
#       "confidence": 0.978189
#     }
#   ]
# }

# %%
response = natural_language_understanding.analyze(
            text = text,
            features = Features(
                        #entities = EntitiesOptions(sentiment = True, emotion = True),
                        keywords = KeywordsOptions(sentiment = True, emotion = True),
                        #concepts = ConceptsOptions(limit = 50),
                        #relations = RelationsOptions(),
                        #sentiment = SentimentOptions(),
                        #semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        #emotion = EmotionOptions(),
                        #categories = CategoriesOptions()
            )).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 230,
#     "features": 1
#   },
#   "language": "en",
#   "keywords": [
#     {
#       "text": "world\u2019s largest luxury automaker",
#       "sentiment": {
#         "score": 0.938528,
#         "label": "positive"
#       },
#       "relevance": 0.880562,
#       "emotion": {
#         "sadness": 0.19455,
#         "joy": 0.595719,
#         "fear": 0.069535,
#         "disgust": 0.050423,
#         "anger": 0.046226
#       },
#       "count": 1
#     },
#     {
#       "text": "last year",
#       "sentiment": {
#         "score": 0.938528,
#         "label": "positive"
#       },
#       "relevance": 0.792378,
#       "emotion": {
#         "sadness": 0.19455,
#         "joy": 0.595719,
#         "fear": 0.069535,
#         "disgust": 0.050423,
#         "anger": 0.046226
#       },
#       "count": 1
#     },
#     {
#       "text": "smaller cars",
#       "sentiment": {
#         "score": 0.938528,
#         "label": "positive"
#       },
#       "relevance": 0.749198,
#       "emotion": {
#         "sadness": 0.19455,
#         "joy": 0.595719,
#         "fear": 0.069535,
#         "disgust": 0.050423,
#         "anger": 0.046226
#       },
#       "count": 1
#     },
#     {
#       "text": "BMW",
#       "sentiment": {
#         "score": 0.938528,
#         "label": "positive"
#       },
#       "relevance": 0.611458,
#       "emotion": {
#         "sadness": 0.19455,
#         "joy": 0.595719,
#         "fear": 0.069535,
#         "disgust": 0.050423,
#         "anger": 0.046226
#       },
#       "count": 1
#     },
#     {
#       "text": "untapped audience",
#       "sentiment": {
#         "score": 0.938528,
#         "label": "positive"
#       },
#       "relevance": 0.606316,
#       "emotion": {
#         "sadness": 0.19455,
#         "joy": 0.595719,
#         "fear": 0.069535,
#         "disgust": 0.050423,
#         "anger": 0.046226
#       },
#       "count": 1
#     },
#     {
#       "text": "Benz",
#       "sentiment": {
#         "score": 0.938528,
#         "label": "positive"
#       },
#       "relevance": 0.569105,
#       "emotion": {
#         "sadness": 0.19455,
#         "joy": 0.595719,
#         "fear": 0.069535,
#         "disgust": 0.050423,
#         "anger": 0.046226
#       },
#       "count": 1
#     },
#     {
#       "text": "attention",
#       "sentiment": {
#         "score": 0.938528,
#         "label": "positive"
#       },
#       "relevance": 0.563321,
#       "emotion": {
#         "sadness": 0.19455,
#         "joy": 0.595719,
#         "fear": 0.069535,
#         "disgust": 0.050423,
#         "anger": 0.046226
#       },
#       "count": 1
#     },
#     {
#       "text": "millennials",
#       "sentiment": {
#         "score": 0.938528,
#         "label": "positive"
#       },
#       "relevance": 0.549141,
#       "emotion": {
#         "sadness": 0.19455,
#         "joy": 0.595719,
#         "fear": 0.069535,
#         "disgust": 0.050423,
#         "anger": 0.046226
#       },
#       "count": 1
#     },
#     {
#       "text": "stages of early adulthood",
#       "sentiment": {
#         "score": 0.938528,
#         "label": "positive"
#       },
#       "relevance": 0.401008,
#       "emotion": {
#         "sadness": 0.19455,
#         "joy": 0.595719,
#         "fear": 0.069535,
#         "disgust": 0.050423,
#         "anger": 0.046226
#       },
#       "count": 1
#     }
#   ]
# }

# %%
response = natural_language_understanding.analyze(
            text = text,
            features = Features(
                        #entities = EntitiesOptions(sentiment = True, emotion = True),
                        #keywords = KeywordsOptions(sentiment = True, emotion = True),
                        concepts = ConceptsOptions(limit = 50),
                        #relations = RelationsOptions(),
                        #sentiment = SentimentOptions(),
                        #semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        #emotion = EmotionOptions(),
                        #categories = CategoriesOptions()
            )).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 230,
#     "features": 1
#   },
#   "language": "en",
#   "concepts": [
#     {
#       "text": "BMW",
#       "relevance": 0.888452,
#       "dbpedia_resource": "http://dbpedia.org/resource/BMW"
#     },
#     {
#       "text": "Mercedes-Benz",
#       "relevance": 0.888266,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mercedes-Benz"
#     },
#     {
#       "text": "Automotive industry",
#       "relevance": 0.882851,
#       "dbpedia_resource": "http://dbpedia.org/resource/Automotive_industry"
#     },
#     {
#       "text": "Luxury vehicle",
#       "relevance": 0.852593,
#       "dbpedia_resource": "http://dbpedia.org/resource/Luxury_vehicle"
#     },
#     {
#       "text": "Karl Benz",
#       "relevance": 0.780259,
#       "dbpedia_resource": "http://dbpedia.org/resource/Karl_Benz"
#     },
#     {
#       "text": "Diesel engine",
#       "relevance": 0.765713,
#       "dbpedia_resource": "http://dbpedia.org/resource/Diesel_engine"
#     },
#     {
#       "text": "World",
#       "relevance": 0.7476,
#       "dbpedia_resource": "http://dbpedia.org/resource/World"
#     },
#     {
#       "text": "Adult",
#       "relevance": 0.72744,
#       "dbpedia_resource": "http://dbpedia.org/resource/Adult"
#     },
#     {
#       "text": "Adulthood",
#       "relevance": 0.714,
#       "dbpedia_resource": "http://dbpedia.org/resource/Adulthood"
#     },
#     {
#       "text": "Earth",
#       "relevance": 0.6804,
#       "dbpedia_resource": "http://dbpedia.org/resource/Earth"
#     }
#   ]
# }

# %%
response = natural_language_understanding.analyze(
            text = text,
            features = Features(
                        #entities = EntitiesOptions(sentiment = True, emotion = True),
                        #keywords = KeywordsOptions(sentiment = True, emotion = True),
                        #concepts = ConceptsOptions(limit = 50),
                        relations = RelationsOptions(),
                        #sentiment = SentimentOptions(),
                        #semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        #emotion = EmotionOptions(),
                        categories = CategoriesOptions())).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 230,
#     "features": 2
#   },
#   "relations": [
#     {
#       "type": "basedIn",
#       "sentence": "After overtaking BMW last year as the world's largest luxury automaker, Mercedes-Benz is turning its attention to a newer, untapped audience: millennials seeking smaller cars as they progress through the stages of early adulthood.",
#       "score": 0.808415,
#       "arguments": [
#         {
#           "text": "automaker",
#           "location": [
#             61,
#             70
#           ],
#           "entities": [
#             {
#               "type": "Organization",
#               "text": "Mercedes-Benz",
#               "disambiguation": {
#                 "subtype": [
#                   "Commercial"
#                 ]
#               }
#             }
#           ]
#         },
#         {
#           "text": "world",
#           "location": [
#             38,
#             43
#           ],
#           "entities": [
#             {
#               "type": "GeopoliticalEntity",
#               "text": "world",
#               "disambiguation": {
#                 "subtype": [
#                   "Area"
#                 ]
#               }
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "employedBy",
#       "sentence": "After overtaking BMW last year as the world's largest luxury automaker, Mercedes-Benz is turning its attention to a newer, untapped audience: millennials seeking smaller cars as they progress through the stages of early adulthood.",
#       "score": 0.31143,
#       "arguments": [
#         {
#           "text": "audience",
#           "location": [
#             132,
#             140
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "audience"
#             }
#           ]
#         },
#         {
#           "text": "its",
#           "location": [
#             97,
#             100
#           ],
#           "entities": [
#             {
#               "type": "Organization",
#               "text": "Mercedes-Benz",
#               "disambiguation": {
#                 "subtype": [
#                   "Commercial"
#                 ]
#               }
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "employedBy",
#       "sentence": "After overtaking BMW last year as the world's largest luxury automaker, Mercedes-Benz is turning its attention to a newer, untapped audience: millennials seeking smaller cars as they progress through the stages of early adulthood.",
#       "score": 0.277355,
#       "arguments": [
#         {
#           "text": "millennials",
#           "location": [
#             142,
#             153
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "millennials"
#             }
#           ]
#         },
#         {
#           "text": "its",
#           "location": [
#             97,
#             100
#           ],
#           "entities": [
#             {
#               "type": "Organization",
#               "text": "Mercedes-Benz",
#               "disambiguation": {
#                 "subtype": [
#                   "Commercial"
#                 ]
#               }
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "locatedAt",
#       "sentence": "After overtaking BMW last year as the world's largest luxury automaker, Mercedes-Benz is turning its attention to a newer, untapped audience: millennials seeking smaller cars as they progress through the stages of early adulthood.",
#       "score": 0.636426,
#       "arguments": [
#         {
#           "text": "millennials",
#           "location": [
#             142,
#             153
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "millennials"
#             }
#           ]
#         },
#         {
#           "text": "cars",
#           "location": [
#             170,
#             174
#           ],
#           "entities": [
#             {
#               "type": "Vehicle",
#               "text": "cars"
#             }
#           ]
#         }
#       ]
#     }
#   ],
#   "language": "en",
#   "categories": [
#     {
#       "score": 0.996276,
#       "label": "/automotive and vehicles/cars"
#     },
#     {
#       "score": 0.983816,
#       "label": "/automotive and vehicles/cars/performance vehicles"
#     },
#     {
#       "score": 0.962343,
#       "label": "/automotive and vehicles/vehicle brands/mercedes-benz"
#     }
#   ]
# }

# %%
response = natural_language_understanding.analyze(
            text = text,
            features = Features(
                        #entities = EntitiesOptions(sentiment = True, emotion = True),
                        #keywords = KeywordsOptions(sentiment = True, emotion = True),
                        #concepts = ConceptsOptions(limit = 50),
                        #relations = RelationsOptions(),
                        sentiment = SentimentOptions(),
                        #semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        #emotion = EmotionOptions(),
                        #categories = CategoriesOptions()
            )).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 230,
#     "features": 1
#   },
#   "sentiment": {
#     "document": {
#       "score": 0.938528,
#       "label": "positive"
#     }
#   },
#   "language": "en"
# }

# %%
response = natural_language_understanding.analyze(
            text = text,
            features = Features(
                        #entities = EntitiesOptions(sentiment = True, emotion = True),
                        #keywords = KeywordsOptions(sentiment = True, emotion = True),
                        #concepts = ConceptsOptions(limit = 50),
                        #relations = RelationsOptions(),
                        #sentiment = SentimentOptions(),
                        semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        #emotion = EmotionOptions(),
                        #categories = CategoriesOptions()
            )).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 230,
#     "features": 1
#   },
#   "semantic_roles": [
#     {
#       "subject": {
#         "text": "the world",
#         "keywords": [
#           {
#             "text": "world"
#           }
#         ]
#       },
#       "sentence": "After overtaking BMW last year as the world\u2019s largest luxury automaker, Mercedes-Benz is turning its attention to a newer, untapped audience: millennials seeking smaller cars as they progress through the stages of early adulthood.",
#       "object": {
#         "text": "largest luxury automaker",
#         "keywords": [
#           {
#             "text": "largest luxury automaker"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "has",
#           "tense": "present"
#         },
#         "text": "s",
#         "normalized": "s"
#       }
#     },
#     {
#       "subject": {
#         "text": "Mercedes-Benz",
#         "keywords": [
#           {
#             "text": "Mercedes-Benz"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Company",
#             "text": "Mercedes-Benz",
#             "disambiguation": {
#               "subtype": [
#                 "Organization",
#                 "AutomotiveDesigner",
#                 "AwardWinner"
#               ],
#               "name": "Mercedes-Benz",
#               "dbpedia_resource": "http://dbpedia.org/resource/Mercedes-Benz"
#             }
#           }
#         ]
#       },
#       "sentence": "After overtaking BMW last year as the world\u2019s largest luxury automaker, Mercedes-Benz is turning its attention to a newer, untapped audience: millennials seeking smaller cars as they progress through the stages of early adulthood.",
#       "object": {
#         "text": "turning its attention to a newer, untapped audience",
#         "keywords": [
#           {
#             "text": "untapped audience"
#           },
#           {
#             "text": "attention"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "present"
#         },
#         "text": "is",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "Mercedes-Benz",
#         "keywords": [
#           {
#             "text": "Mercedes-Benz"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Company",
#             "text": "Mercedes-Benz",
#             "disambiguation": {
#               "subtype": [
#                 "Organization",
#                 "AutomotiveDesigner",
#                 "AwardWinner"
#               ],
#               "name": "Mercedes-Benz",
#               "dbpedia_resource": "http://dbpedia.org/resource/Mercedes-Benz"
#             }
#           }
#         ]
#       },
#       "sentence": "After overtaking BMW last year as the world\u2019s largest luxury automaker, Mercedes-Benz is turning its attention to a newer, untapped audience: millennials seeking smaller cars as they progress through the stages of early adulthood.",
#       "object": {
#         "text": "its attention",
#         "keywords": [
#           {
#             "text": "attention"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "turn",
#           "tense": "present"
#         },
#         "text": "is turning",
#         "normalized": "be turn"
#       }
#     },
#     {
#       "subject": {
#         "text": "millennials",
#         "keywords": [
#           {
#             "text": "millennials"
#           }
#         ]
#       },
#       "sentence": "After overtaking BMW last year as the world\u2019s largest luxury automaker, Mercedes-Benz is turning its attention to a newer, untapped audience: millennials seeking smaller cars as they progress through the stages of early adulthood.",
#       "object": {
#         "text": "smaller cars",
#         "keywords": [
#           {
#             "text": "smaller cars"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "seek",
#           "tense": "present"
#         },
#         "text": "seeking",
#         "normalized": "seek"
#       }
#     }
#   ],
#   "language": "en"
# }

# %%
response = natural_language_understanding.analyze(
            text = text,
            features = Features(
                        #entities = EntitiesOptions(sentiment = True, emotion = True),
                        #keywords = KeywordsOptions(sentiment = True, emotion = True),
                        #concepts = ConceptsOptions(limit = 50),
                        #relations = RelationsOptions(),
                        #sentiment = SentimentOptions(),
                        #semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        emotion = EmotionOptions(),
                        #categories = CategoriesOptions()
            )).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 230,
#     "features": 1
#   },
#   "language": "en",
#   "emotion": {
#     "document": {
#       "emotion": {
#         "sadness": 0.19455,
#         "joy": 0.595719,
#         "fear": 0.069535,
#         "disgust": 0.050423,
#         "anger": 0.046226
#       }
#     }
#   }
# }

# %%
response = natural_language_understanding.analyze(
            text = text,
            features = Features(
                        #entities = EntitiesOptions(sentiment = True, emotion = True),
                        #keywords = KeywordsOptions(sentiment = True, emotion = True),
                        #concepts = ConceptsOptions(limit = 50),
                        #relations = RelationsOptions(),
                        #sentiment = SentimentOptions(),
                        #semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        #emotion = EmotionOptions(),
                        categories = CategoriesOptions()
            )).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 230,
#     "features": 1
#   },
#   "language": "en",
#   "categories": [
#     {
#       "score": 0.996276,
#       "label": "/automotive and vehicles/cars"
#     },
#     {
#       "score": 0.983816,
#       "label": "/automotive and vehicles/cars/performance vehicles"
#     },
#     {
#       "score": 0.962343,
#       "label": "/automotive and vehicles/vehicle brands/mercedes-benz"
#     }
#   ]
# }

# %% [markdown]
# ## Analyzing URLS

# %%
url='https://www.chicagotribune.com/news/criminal-justice/ct-fatal-chicago-police-shooting-hearing-20190809-kmahnsrqirff5c52aqnjrgl64i-story.html'

response = natural_language_understanding.analyze(
            url = url,
            features = Features(
                        entities = EntitiesOptions(sentiment = True, emotion = True),
                        keywords = KeywordsOptions(sentiment = True, emotion = True),
                        concepts = ConceptsOptions(limit = 50),
                        #relations = RelationsOptions(),
                        #sentiment = SentimentOptions(),
                        #semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        #emotion = EmotionOptions(),
                        #categories = CategoriesOptions()
            )).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 1592,
#     "features": 3
#   },
#   "retrieved_url": "https://www.chicagotribune.com/news/criminal-justice/ct-fatal-chicago-police-shooting-hearing-20190809-kmahnsrqirff5c52aqnjrgl64i-story.html",
#   "language": "en",
#   "keywords": [
#     {
#       "text": "Chicago police officer",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.736369,
#       "emotion": {
#         "sadness": 0.490538,
#         "joy": 0.042388,
#         "fear": 0.17918,
#         "disgust": 0.333886,
#         "anger": 0.289149
#       },
#       "count": 1
#     },
#     {
#       "text": "high-speed car chase",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.718916,
#       "emotion": {
#         "sadness": 0.490538,
#         "joy": 0.042388,
#         "fear": 0.17918,
#         "disgust": 0.333886,
#         "anger": 0.289149
#       },
#       "count": 1
#     },
#     {
#       "text": "Officer Jose Diaz",
#       "sentiment": {
#         "score": -0.789158,
#         "label": "negative"
#       },
#       "relevance": 0.650066,
#       "emotion": {
#         "sadness": 0.559441,
#         "joy": 0.009198,
#         "fear": 0.327919,
#         "disgust": 0.29717,
#         "anger": 0.172976
#       },
#       "count": 1
#     },
#     {
#       "text": "second day of a Chicago Police Board",
#       "sentiment": {
#         "score": -0.789158,
#         "label": "negative"
#       },
#       "relevance": 0.623874,
#       "emotion": {
#         "sadness": 0.559441,
#         "joy": 0.009198,
#         "fear": 0.327919,
#         "disgust": 0.29717,
#         "anger": 0.172976
#       },
#       "count": 1
#     },
#     {
#       "text": "dangerous situation",
#       "sentiment": {
#         "score": -0.750967,
#         "label": "negative"
#       },
#       "relevance": 0.606233,
#       "emotion": {
#         "sadness": 0.34406,
#         "joy": 0.093492,
#         "fear": 0.456748,
#         "disgust": 0.098526,
#         "anger": 0.28716
#       },
#       "count": 1
#     },
#     {
#       "text": "South Side backyard",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.598566,
#       "emotion": {
#         "sadness": 0.490538,
#         "joy": 0.042388,
#         "fear": 0.17918,
#         "disgust": 0.333886,
#         "anger": 0.289149
#       },
#       "count": 1
#     },
#     {
#       "text": "black teen",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.570405,
#       "emotion": {
#         "sadness": 0.490538,
#         "joy": 0.042388,
#         "fear": 0.17918,
#         "disgust": 0.333886,
#         "anger": 0.289149
#       },
#       "count": 1
#     },
#     {
#       "text": "testimony Friday",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.562357,
#       "emotion": {
#         "sadness": 0.343304,
#         "joy": 0.060676,
#         "fear": 0.365313,
#         "disgust": 0.253897,
#         "anger": 0.254019
#       },
#       "count": 1
#     },
#     {
#       "text": "Jaguar\u2019s driver",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.557504,
#       "emotion": {
#         "sadness": 0.228139,
#         "joy": 0.202955,
#         "fear": 0.258126,
#         "disgust": 0.190957,
#         "anger": 0.277431
#       },
#       "count": 1
#     },
#     {
#       "text": "moving vehicle",
#       "sentiment": {
#         "score": -0.862305,
#         "label": "negative"
#       },
#       "relevance": 0.553958,
#       "emotion": {
#         "sadness": 0.269131,
#         "joy": 0.047288,
#         "fear": 0.606128,
#         "disgust": 0.06713,
#         "anger": 0.147311
#       },
#       "count": 1
#     },
#     {
#       "text": "police SUV",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.543759,
#       "emotion": {
#         "sadness": 0.490538,
#         "joy": 0.042388,
#         "fear": 0.17918,
#         "disgust": 0.333886,
#         "anger": 0.289149
#       },
#       "count": 1
#     },
#     {
#       "text": "evening shift",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.538691,
#       "emotion": {
#         "sadness": 0.343304,
#         "joy": 0.060676,
#         "fear": 0.365313,
#         "disgust": 0.253897,
#         "anger": 0.254019
#       },
#       "count": 1
#     },
#     {
#       "text": "fire",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.537323,
#       "emotion": {
#         "sadness": 0.398666,
#         "joy": 0.012286,
#         "fear": 0.562318,
#         "disgust": 0.220542,
#         "anger": 0.186449
#       },
#       "count": 1
#     },
#     {
#       "text": "vehicle",
#       "sentiment": {
#         "score": -0.87593,
#         "label": "negative"
#       },
#       "relevance": 0.527229,
#       "emotion": {
#         "sadness": 0.561313,
#         "joy": 0.004073,
#         "fear": 0.312949,
#         "disgust": 0.119962,
#         "anger": 0.375171
#       },
#       "count": 3
#     },
#     {
#       "text": "partner",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.525256,
#       "emotion": {
#         "sadness": 0.405825,
#         "joy": 0.038607,
#         "fear": 0.54096,
#         "disgust": 0.090013,
#         "anger": 0.252512
#       },
#       "count": 3
#     },
#     {
#       "text": "record",
#       "sentiment": {
#         "score": -0.750967,
#         "label": "negative"
#       },
#       "relevance": 0.52217,
#       "emotion": {
#         "sadness": 0.34406,
#         "joy": 0.093492,
#         "fear": 0.456748,
#         "disgust": 0.098526,
#         "anger": 0.28716
#       },
#       "count": 1
#     },
#     {
#       "text": "Coughlin",
#       "sentiment": {
#         "score": -0.828813,
#         "label": "negative"
#       },
#       "relevance": 0.521939,
#       "emotion": {
#         "sadness": 0.090551,
#         "joy": 0.053824,
#         "fear": 0.870616,
#         "disgust": 0.04124,
#         "anger": 0.078156
#       },
#       "count": 2
#     },
#     {
#       "text": "Torres",
#       "sentiment": {
#         "score": -0.828813,
#         "label": "negative"
#       },
#       "relevance": 0.519708,
#       "emotion": {
#         "sadness": 0.090551,
#         "joy": 0.053824,
#         "fear": 0.870616,
#         "disgust": 0.04124,
#         "anger": 0.078156
#       },
#       "count": 2
#     },
#     {
#       "text": "car",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.5184,
#       "emotion": {
#         "sadness": 0.440044,
#         "joy": 0.023741,
#         "fear": 0.282347,
#         "disgust": 0.1603,
#         "anger": 0.463398
#       },
#       "count": 3
#     },
#     {
#       "text": "child abuse case",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.517677,
#       "emotion": {
#         "sadness": 0.343304,
#         "joy": 0.060676,
#         "fear": 0.365313,
#         "disgust": 0.253897,
#         "anger": 0.254019
#       },
#       "count": 1
#     },
#     {
#       "text": "Diaz",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.516426,
#       "emotion": {
#         "sadness": 0.487941,
#         "joy": 0.008661,
#         "fear": 0.367737,
#         "disgust": 0.310374,
#         "anger": 0.216251
#       },
#       "count": 1
#     },
#     {
#       "text": "firearm",
#       "sentiment": {
#         "score": -0.750967,
#         "label": "negative"
#       },
#       "relevance": 0.514213,
#       "emotion": {
#         "sadness": 0.34406,
#         "joy": 0.093492,
#         "fear": 0.456748,
#         "disgust": 0.098526,
#         "anger": 0.28716
#       },
#       "count": 1
#     },
#     {
#       "text": "holster",
#       "sentiment": {
#         "score": -0.750967,
#         "label": "negative"
#       },
#       "relevance": 0.514154,
#       "emotion": {
#         "sadness": 0.34406,
#         "joy": 0.093492,
#         "fear": 0.456748,
#         "disgust": 0.098526,
#         "anger": 0.28716
#       },
#       "count": 1
#     },
#     {
#       "text": "moments",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.514074,
#       "emotion": {
#         "sadness": 0.490538,
#         "joy": 0.042388,
#         "fear": 0.17918,
#         "disgust": 0.333886,
#         "anger": 0.289149
#       },
#       "count": 1
#     },
#     {
#       "text": "fear of their lives",
#       "sentiment": {
#         "score": -0.828813,
#         "label": "negative"
#       },
#       "relevance": 0.512236,
#       "emotion": {
#         "sadness": 0.035014,
#         "joy": 0.053161,
#         "fear": 0.911837,
#         "disgust": 0.055047,
#         "anger": 0.021351
#       },
#       "count": 1
#     },
#     {
#       "text": "chase",
#       "sentiment": {
#         "score": -0.927574,
#         "label": "negative"
#       },
#       "relevance": 0.51122,
#       "emotion": {
#         "sadness": 0.50097,
#         "joy": 0.013045,
#         "fear": 0.15758,
#         "disgust": 0.190331,
#         "anger": 0.484459
#       },
#       "count": 1
#     },
#     {
#       "text": "suspects",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.510492,
#       "emotion": {
#         "sadness": 0.343304,
#         "joy": 0.060676,
#         "fear": 0.365313,
#         "disgust": 0.253897,
#         "anger": 0.254019
#       },
#       "count": 1
#     },
#     {
#       "text": "Jaguar",
#       "sentiment": {
#         "score": -0.927574,
#         "label": "negative"
#       },
#       "relevance": 0.510442,
#       "emotion": {
#         "sadness": 0.265502,
#         "joy": 0.07244,
#         "fear": 0.526112,
#         "disgust": 0.168292,
#         "anger": 0.295275
#       },
#       "count": 2
#     },
#     {
#       "text": "weapon",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.507308,
#       "emotion": {
#         "sadness": 0.603718,
#         "joy": 0.094448,
#         "fear": 0.311248,
#         "disgust": 0.020855,
#         "anger": 0.176955
#       },
#       "count": 1
#     },
#     {
#       "text": "collision",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.507207,
#       "emotion": {
#         "sadness": 0.490538,
#         "joy": 0.042388,
#         "fear": 0.17918,
#         "disgust": 0.333886,
#         "anger": 0.289149
#       },
#       "count": 1
#     },
#     {
#       "text": "sports car",
#       "sentiment": {
#         "score": -0.927574,
#         "label": "negative"
#       },
#       "relevance": 0.506999,
#       "emotion": {
#         "sadness": 0.321686,
#         "joy": 0.007478,
#         "fear": 0.140706,
#         "disgust": 0.065263,
#         "anger": 0.615986
#       },
#       "count": 1
#     },
#     {
#       "text": "missile",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.506857,
#       "emotion": {
#         "sadness": 0.228139,
#         "joy": 0.202955,
#         "fear": 0.258126,
#         "disgust": 0.190957,
#         "anger": 0.277431
#       },
#       "count": 1
#     },
#     {
#       "text": "reason",
#       "sentiment": {
#         "score": -0.750967,
#         "label": "negative"
#       },
#       "relevance": 0.506743,
#       "emotion": {
#         "sadness": 0.34406,
#         "joy": 0.093492,
#         "fear": 0.456748,
#         "disgust": 0.098526,
#         "anger": 0.28716
#       },
#       "count": 1
#     },
#     {
#       "text": "traffic",
#       "sentiment": {
#         "score": -0.750967,
#         "label": "negative"
#       },
#       "relevance": 0.503795,
#       "emotion": {
#         "sadness": 0.321686,
#         "joy": 0.007478,
#         "fear": 0.140706,
#         "disgust": 0.065263,
#         "anger": 0.615986
#       },
#       "count": 1
#     },
#     {
#       "text": "area",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.503795,
#       "emotion": {
#         "sadness": 0.603718,
#         "joy": 0.094448,
#         "fear": 0.311248,
#         "disgust": 0.020855,
#         "anger": 0.176955
#       },
#       "count": 1
#     },
#     {
#       "text": "hearing",
#       "sentiment": {
#         "score": -0.828813,
#         "label": "negative"
#       },
#       "relevance": 0.479211,
#       "emotion": {
#         "sadness": 0.274483,
#         "joy": 0.011175,
#         "fear": 0.713846,
#         "disgust": 0.231186,
#         "anger": 0.10051
#       },
#       "count": 1
#     },
#     {
#       "text": "Friday",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.472723,
#       "emotion": {
#         "sadness": 0.449453,
#         "joy": 0.022596,
#         "fear": 0.227373,
#         "disgust": 0.368461,
#         "anger": 0.313312
#       },
#       "count": 1
#     },
#     {
#       "text": "male",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.458891,
#       "emotion": {
#         "sadness": 0.490538,
#         "joy": 0.042388,
#         "fear": 0.17918,
#         "disgust": 0.333886,
#         "anger": 0.289149
#       },
#       "count": 1
#     },
#     {
#       "text": "Thursday",
#       "sentiment": {
#         "score": -0.828813,
#         "label": "negative"
#       },
#       "relevance": 0.458783,
#       "emotion": {
#         "sadness": 0.035014,
#         "joy": 0.053161,
#         "fear": 0.911837,
#         "disgust": 0.055047,
#         "anger": 0.021351
#       },
#       "count": 1
#     },
#     {
#       "text": "fatal police shooting of 18-year-old Paul O\u2019Neal",
#       "sentiment": {
#         "score": -0.789158,
#         "label": "negative"
#       },
#       "relevance": 0.456452,
#       "emotion": {
#         "sadness": 0.559441,
#         "joy": 0.009198,
#         "fear": 0.327919,
#         "disgust": 0.29717,
#         "anger": 0.172976
#       },
#       "count": 1
#     },
#     {
#       "text": "July",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.455008,
#       "emotion": {
#         "sadness": 0.343304,
#         "joy": 0.060676,
#         "fear": 0.365313,
#         "disgust": 0.253897,
#         "anger": 0.254019
#       },
#       "count": 1
#     },
#     {
#       "text": "turns",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.450904,
#       "emotion": {
#         "sadness": 0.228139,
#         "joy": 0.202955,
#         "fear": 0.258126,
#         "disgust": 0.190957,
#         "anger": 0.277431
#       },
#       "count": 1
#     },
#     {
#       "text": "Epperson",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.448272,
#       "emotion": {
#         "sadness": 0.228139,
#         "joy": 0.202955,
#         "fear": 0.258126,
#         "disgust": 0.190957,
#         "anger": 0.277431
#       },
#       "count": 1
#     }
#   ],
#   "entities": [
#     {
#       "type": "Person",
#       "text": "Jose Diaz",
#       "sentiment": {
#         "score": -0.789158,
#         "label": "negative"
#       },
#       "relevance": 0.951255,
#       "emotion": {
#         "sadness": 0.559441,
#         "joy": 0.009198,
#         "fear": 0.327919,
#         "disgust": 0.29717,
#         "anger": 0.172976
#       },
#       "count": 1,
#       "confidence": 0.698869
#     },
#     {
#       "type": "Organization",
#       "text": "Chicago Police Board",
#       "sentiment": {
#         "score": -0.789158,
#         "label": "negative"
#       },
#       "relevance": 0.924309,
#       "emotion": {
#         "sadness": 0.559441,
#         "joy": 0.009198,
#         "fear": 0.327919,
#         "disgust": 0.29717,
#         "anger": 0.172976
#       },
#       "disambiguation": {
#         "subtype": [
#           "GovernmentAgency"
#         ],
#         "name": "Chicago_Police_Department",
#         "dbpedia_resource": "http://dbpedia.org/resource/Chicago_Police_Department"
#       },
#       "count": 1,
#       "confidence": 0.717188
#     },
#     {
#       "type": "Person",
#       "text": "Paul O\u2019",
#       "sentiment": {
#         "score": -0.789158,
#         "label": "negative"
#       },
#       "relevance": 0.884494,
#       "emotion": {
#         "sadness": 0.559441,
#         "joy": 0.009198,
#         "fear": 0.327919,
#         "disgust": 0.29717,
#         "anger": 0.172976
#       },
#       "count": 1,
#       "confidence": 0.95287
#     },
#     {
#       "type": "Person",
#       "text": "Coughlin",
#       "sentiment": {
#         "score": -0.828813,
#         "label": "negative"
#       },
#       "relevance": 0.713838,
#       "emotion": {
#         "sadness": 0.090551,
#         "joy": 0.053824,
#         "fear": 0.870616,
#         "disgust": 0.04124,
#         "anger": 0.078156
#       },
#       "count": 2,
#       "confidence": 1
#     },
#     {
#       "type": "Person",
#       "text": "Torres",
#       "sentiment": {
#         "score": -0.828813,
#         "label": "negative"
#       },
#       "relevance": 0.59885,
#       "emotion": {
#         "sadness": 0.090551,
#         "joy": 0.053824,
#         "fear": 0.870616,
#         "disgust": 0.04124,
#         "anger": 0.078156
#       },
#       "count": 2,
#       "confidence": 0.999998
#     },
#     {
#       "type": "Quantity",
#       "text": "18-year",
#       "sentiment": {
#         "score": -0.789158,
#         "label": "negative"
#       },
#       "relevance": 0.584424,
#       "emotion": {
#         "sadness": 0.559441,
#         "joy": 0.009198,
#         "fear": 0.327919,
#         "disgust": 0.29717,
#         "anger": 0.172976
#       },
#       "count": 1,
#       "confidence": 0.8
#     },
#     {
#       "type": "Person",
#       "text": "Epperson",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.561188,
#       "emotion": {
#         "sadness": 0.228139,
#         "joy": 0.202955,
#         "fear": 0.258126,
#         "disgust": 0.190957,
#         "anger": 0.277431
#       },
#       "count": 1,
#       "confidence": 0.999771
#     },
#     {
#       "type": "Location",
#       "text": "Chicago",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.473909,
#       "emotion": {
#         "sadness": 0.490538,
#         "joy": 0.042388,
#         "fear": 0.17918,
#         "disgust": 0.333886,
#         "anger": 0.289149
#       },
#       "count": 1,
#       "confidence": 0.927374
#     },
#     {
#       "type": "Person",
#       "text": "Neal",
#       "sentiment": {
#         "score": -0.789158,
#         "label": "negative"
#       },
#       "relevance": 0.468323,
#       "emotion": {
#         "sadness": 0.559441,
#         "joy": 0.009198,
#         "fear": 0.327919,
#         "disgust": 0.29717,
#         "anger": 0.172976
#       },
#       "count": 1,
#       "confidence": 0.936405
#     },
#     {
#       "type": "Person",
#       "text": "Diaz",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.251967,
#       "emotion": {
#         "sadness": 0.343304,
#         "joy": 0.060676,
#         "fear": 0.365313,
#         "disgust": 0.253897,
#         "anger": 0.254019
#       },
#       "count": 1,
#       "confidence": 0.983838
#     }
#   ],
#   "concepts": [
#     {
#       "text": "Police",
#       "relevance": 0.917609,
#       "dbpedia_resource": "http://dbpedia.org/resource/Police"
#     },
#     {
#       "text": "Police brutality",
#       "relevance": 0.80525,
#       "dbpedia_resource": "http://dbpedia.org/resource/Police_brutality"
#     },
#     {
#       "text": "Chicago Police Department",
#       "relevance": 0.775767,
#       "dbpedia_resource": "http://dbpedia.org/resource/Chicago_Police_Department"
#     },
#     {
#       "text": "Year of birth missing",
#       "relevance": 0.769943,
#       "dbpedia_resource": "http://dbpedia.org/resource/Year_of_birth_missing_(living_people)"
#     },
#     {
#       "text": "Testimony",
#       "relevance": 0.675108,
#       "dbpedia_resource": "http://dbpedia.org/resource/Testimony"
#     },
#     {
#       "text": "Strike from the record",
#       "relevance": 0.642216,
#       "dbpedia_resource": "http://dbpedia.org/resource/Strike_from_the_record"
#     },
#     {
#       "text": "2016",
#       "relevance": 0.6141,
#       "dbpedia_resource": "http://dbpedia.org/resource/2016"
#     },
#     {
#       "text": "Dangerous",
#       "relevance": 0.613952,
#       "dbpedia_resource": "http://dbpedia.org/resource/Dangerous"
#     },
#     {
#       "text": "Jacksonville Jaguars",
#       "relevance": 0.609892,
#       "dbpedia_resource": "http://dbpedia.org/resource/Jacksonville_Jaguars"
#     },
#     {
#       "text": "Jaguar",
#       "relevance": 0.59754,
#       "dbpedia_resource": "http://dbpedia.org/resource/Jaguar"
#     }
#   ]
# }

# %%
response = natural_language_understanding.analyze(
            url = url,
            features = Features(
                        #entities = EntitiesOptions(sentiment = True, emotion = True),
                        #keywords = KeywordsOptions(sentiment = True, emotion = True),
                        #concepts = ConceptsOptions(limit = 50),
                        #relations = RelationsOptions(),
                        #sentiment = SentimentOptions(),
                        semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        #emotion = EmotionOptions(),
                        #categories = CategoriesOptions()
            )).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 1592,
#     "features": 1
#   },
#   "semantic_roles": [
#     {
#       "subject": {
#         "text": "A Chicago police officer",
#         "keywords": [
#           {
#             "text": "Chicago police officer"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Location",
#             "text": "Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ],
#               "name": "Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/Chicago"
#             }
#           },
#           {
#             "type": "JobTitle",
#             "text": "officer"
#           }
#         ]
#       },
#       "sentence": " A Chicago police officer who fatally shot a black teen in a South Side backyard in 2016 testified Friday he believed the male had fired at him moments earlier during a chaotic, high-speed car chase that ended in a collision with his police SUV.",
#       "object": {
#         "text": "a black teen",
#         "keywords": [
#           {
#             "text": "black teen"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "shoot",
#           "tense": "past"
#         },
#         "text": "shot",
#         "normalized": "shoot"
#       }
#     },
#     {
#       "subject": {
#         "text": "A Chicago police officer who fatally shot a black teen in a South Side backyard in 2016",
#         "keywords": [
#           {
#             "text": "Chicago police officer"
#           },
#           {
#             "text": "South Side backyard"
#           },
#           {
#             "text": "black teen"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Location",
#             "text": "Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ],
#               "name": "Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/Chicago"
#             }
#           },
#           {
#             "type": "JobTitle",
#             "text": "officer"
#           }
#         ]
#       },
#       "sentence": " A Chicago police officer who fatally shot a black teen in a South Side backyard in 2016 testified Friday he believed the male had fired at him moments earlier during a chaotic, high-speed car chase that ended in a collision with his police SUV.",
#       "object": {
#         "text": "he believed the male had fired at him moments earlier during a chaotic, high-speed car chase that ended in a collision with his police SUV",
#         "keywords": [
#           {
#             "text": "high-speed car chase"
#           },
#           {
#             "text": "police SUV"
#           },
#           {
#             "text": "moments"
#           },
#           {
#             "text": "collision"
#           }
#         ],
#         "entities": []
#       },
#       "action": {
#         "verb": {
#           "text": "testify",
#           "tense": "past"
#         },
#         "text": "testified",
#         "normalized": "testify"
#       }
#     },
#     {
#       "subject": {
#         "text": "the male"
#       },
#       "sentence": " A Chicago police officer who fatally shot a black teen in a South Side backyard in 2016 testified Friday he believed the male had fired at him moments earlier during a chaotic, high-speed car chase that ended in a collision with his police SUV.",
#       "action": {
#         "verb": {
#           "text": "fire",
#           "tense": "past"
#         },
#         "text": "had fired",
#         "normalized": "have fire"
#       }
#     },
#     {
#       "subject": {
#         "text": "a chaotic, high-speed car chase",
#         "keywords": [
#           {
#             "text": "high-speed car chase"
#           }
#         ],
#         "entities": []
#       },
#       "sentence": " A Chicago police officer who fatally shot a black teen in a South Side backyard in 2016 testified Friday he believed the male had fired at him moments earlier during a chaotic, high-speed car chase that ended in a collision with his police SUV.",
#       "action": {
#         "verb": {
#           "text": "end",
#           "tense": "past"
#         },
#         "text": "ended",
#         "normalized": "end"
#       }
#     },
#     {
#       "subject": {
#         "text": "I"
#       },
#       "sentence": " \u201cI was convinced wholeheartedly that he had fired upon me previously, had tried to hurt us with the vehicle,\u201d Officer Jose Diaz said during the second day of a Chicago Police Board hearing into the fatal police shooting of 18-year-old Paul O\u2019Neal.",
#       "object": {
#         "text": "convinced wholeheartedly that he had fired upon me previously, had tried to hurt us with the vehicle",
#         "keywords": [
#           {
#             "text": "vehicle"
#           }
#         ],
#         "entities": []
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "past"
#         },
#         "text": "was",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "he",
#         "entities": []
#       },
#       "sentence": " \u201cI was convinced wholeheartedly that he had fired upon me previously, had tried to hurt us with the vehicle,\u201d Officer Jose Diaz said during the second day of a Chicago Police Board hearing into the fatal police shooting of 18-year-old Paul O\u2019Neal.",
#       "action": {
#         "verb": {
#           "text": "fire",
#           "tense": "past"
#         },
#         "text": "had fired",
#         "normalized": "have fire"
#       }
#     },
#     {
#       "subject": {
#         "text": "he",
#         "entities": []
#       },
#       "sentence": " \u201cI was convinced wholeheartedly that he had fired upon me previously, had tried to hurt us with the vehicle,\u201d Officer Jose Diaz said during the second day of a Chicago Police Board hearing into the fatal police shooting of 18-year-old Paul O\u2019Neal.",
#       "object": {
#         "text": "us"
#       },
#       "action": {
#         "verb": {
#           "text": "hurt",
#           "tense": "past"
#         },
#         "text": "had tried to hurt",
#         "normalized": "have try to hurt"
#       }
#     },
#     {
#       "subject": {
#         "text": "Officer Jose Diaz",
#         "keywords": [
#           {
#             "text": "Officer Jose Diaz"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Person",
#             "text": "Officer Jose Diaz"
#           }
#         ]
#       },
#       "sentence": " \u201cI was convinced wholeheartedly that he had fired upon me previously, had tried to hurt us with the vehicle,\u201d Officer Jose Diaz said during the second day of a Chicago Police Board hearing into the fatal police shooting of 18-year-old Paul O\u2019Neal.",
#       "action": {
#         "verb": {
#           "text": "say",
#           "tense": "past"
#         },
#         "text": "said",
#         "normalized": "say"
#       }
#     },
#     {
#       "subject": {
#         "text": "a Chicago Police Board",
#         "keywords": [
#           {
#             "text": "Chicago Police Board"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "Chicago Police Board",
#             "disambiguation": {
#               "subtype": [
#                 "GovernmentAgency"
#               ],
#               "name": "Chicago Police Department",
#               "dbpedia_resource": "http://dbpedia.org/resource/Chicago_Police_Department"
#             }
#           }
#         ]
#       },
#       "sentence": " \u201cI was convinced wholeheartedly that he had fired upon me previously, had tried to hurt us with the vehicle,\u201d Officer Jose Diaz said during the second day of a Chicago Police Board hearing into the fatal police shooting of 18-year-old Paul O\u2019Neal.",
#       "object": {
#         "text": "into the fatal police shooting of 18-year-old Paul O\u2019Neal",
#         "keywords": [
#           {
#             "text": "fatal police shooting"
#           },
#           {
#             "text": "18-year-old Paul O\u2019Neal"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Person",
#             "text": "Paul O\u2019Neal"
#           },
#           {
#             "type": "Quantity",
#             "text": "18-year"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "hear",
#           "tense": "present"
#         },
#         "text": "hearing",
#         "normalized": "hear"
#       }
#     },
#     {
#       "subject": {
#         "text": "they"
#       },
#       "sentence": " Even if they had succeeded in shooting the Jaguar\u2019s driver, the car \"turns into a missile,\u201d Epperson testified.",
#       "object": {
#         "text": "succeeded"
#       },
#       "action": {
#         "verb": {
#           "text": "have",
#           "tense": "past"
#         },
#         "text": "had",
#         "normalized": "have"
#       }
#     },
#     {
#       "subject": {
#         "text": "they"
#       },
#       "sentence": " Even if they had succeeded in shooting the Jaguar\u2019s driver, the car \"turns into a missile,\u201d Epperson testified.",
#       "object": {
#         "text": "in shooting the Jaguar\u2019s driver",
#         "keywords": [
#           {
#             "text": "Jaguar\u2019s driver"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "succeed",
#           "tense": "past"
#         },
#         "text": "had succeeded",
#         "normalized": "have succeed"
#       }
#     },
#     {
#       "subject": {
#         "text": "they"
#       },
#       "sentence": " Even if they had succeeded in shooting the Jaguar\u2019s driver, the car \"turns into a missile,\u201d Epperson testified.",
#       "object": {
#         "text": "the Jaguar\u2019s driver",
#         "keywords": [
#           {
#             "text": "Jaguar\u2019s driver"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "shoot",
#           "tense": "past"
#         },
#         "text": "shooting",
#         "normalized": "shoot"
#       }
#     },
#     {
#       "subject": {
#         "text": "the car",
#         "keywords": [
#           {
#             "text": "car"
#           }
#         ]
#       },
#       "sentence": " Even if they had succeeded in shooting the Jaguar\u2019s driver, the car \"turns into a missile,\u201d Epperson testified.",
#       "object": {
#         "text": "into a missile",
#         "keywords": [
#           {
#             "text": "missile"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "turn",
#           "tense": "present"
#         },
#         "text": "turns",
#         "normalized": "turn"
#       }
#     },
#     {
#       "subject": {
#         "text": "Epperson",
#         "keywords": [
#           {
#             "text": "Epperson"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Person",
#             "text": "Epperson"
#           }
#         ]
#       },
#       "sentence": " Even if they had succeeded in shooting the Jaguar\u2019s driver, the car \"turns into a missile,\u201d Epperson testified.",
#       "object": {
#         "text": "the car \"turns into a missile",
#         "keywords": [
#           {
#             "text": "missile"
#           },
#           {
#             "text": "car"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "testify",
#           "tense": "past"
#         },
#         "text": "testified",
#         "normalized": "testify"
#       }
#     },
#     {
#       "subject": {
#         "text": "It"
#       },
#       "sentence": " It\u2019s inherently dangerous to shoot at a moving vehicle.\u201d",
#       "object": {
#         "text": "inherently dangerous to shoot at a moving vehicle",
#         "keywords": [
#           {
#             "text": "vehicle"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "has",
#           "tense": "present"
#         },
#         "text": "s",
#         "normalized": "s"
#       }
#     },
#     {
#       "subject": {
#         "text": "The hearing",
#         "keywords": [
#           {
#             "text": "hearing"
#           }
#         ]
#       },
#       "sentence": " The hearing started Thursday with Coughlin and Torres testifying that they were in fear of their lives when they opened fire.",
#       "action": {
#         "verb": {
#           "text": "start",
#           "tense": "past"
#         },
#         "text": "started",
#         "normalized": "start"
#       }
#     },
#     {
#       "subject": {
#         "text": "Torres",
#         "keywords": [
#           {
#             "text": "Torres"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Person",
#             "text": "Torres"
#           }
#         ]
#       },
#       "sentence": " The hearing started Thursday with Coughlin and Torres testifying that they were in fear of their lives when they opened fire.",
#       "object": {
#         "text": "that they were in fear of their lives when they opened fire",
#         "keywords": [
#           {
#             "text": "fear"
#           },
#           {
#             "text": "lives"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "testify",
#           "tense": "present"
#         },
#         "text": "testifying",
#         "normalized": "testify"
#       }
#     },
#     {
#       "subject": {
#         "text": "they"
#       },
#       "sentence": " The hearing started Thursday with Coughlin and Torres testifying that they were in fear of their lives when they opened fire.",
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "past"
#         },
#         "text": "were",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "Coughlin",
#         "keywords": [
#           {
#             "text": "Coughlin"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Person",
#             "text": "Coughlin"
#           }
#         ]
#       },
#       "sentence": " Coughlin said he initially thought the Jaguar had run over his partner, while Torres, who managed to dodge the car, testified he thought the car was going to strike him.",
#       "object": {
#         "text": "he initially thought the Jaguar had run over his partner, while Torres, who managed to dodge the car, testified he thought the car was going to strike him",
#         "keywords": [
#           {
#             "text": "car"
#           },
#           {
#             "text": "Torres"
#           },
#           {
#             "text": "Jaguar"
#           },
#           {
#             "text": "partner"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Person",
#             "text": "Coughlin"
#           },
#           {
#             "type": "JobTitle",
#             "text": "partner"
#           },
#           {
#             "type": "Person",
#             "text": "Torres"
#           },
#           {
#             "type": "Person",
#             "text": "Torres"
#           },
#           {
#             "type": "Person",
#             "text": "Torres"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "say",
#           "tense": "past"
#         },
#         "text": "said",
#         "normalized": "say"
#       }
#     },
#     {
#       "subject": {
#         "text": "he",
#         "entities": [
#           {
#             "type": "Person",
#             "text": "Coughlin"
#           }
#         ]
#       },
#       "sentence": " Coughlin said he initially thought the Jaguar had run over his partner, while Torres, who managed to dodge the car, testified he thought the car was going to strike him.",
#       "object": {
#         "text": "the Jaguar had run over his partner, while Torres, who managed to dodge the car",
#         "keywords": [
#           {
#             "text": "Torres"
#           },
#           {
#             "text": "Jaguar"
#           },
#           {
#             "text": "partner"
#           },
#           {
#             "text": "car"
#           }
#         ],
#         "entities": [
#           {
#             "type": "JobTitle",
#             "text": "partner"
#           },
#           {
#             "type": "Person",
#             "text": "Torres"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "think",
#           "tense": "past"
#         },
#         "text": "thought",
#         "normalized": "think"
#       }
#     },
#     {
#       "subject": {
#         "text": "the Jaguar",
#         "keywords": [
#           {
#             "text": "Jaguar"
#           }
#         ]
#       },
#       "sentence": " Coughlin said he initially thought the Jaguar had run over his partner, while Torres, who managed to dodge the car, testified he thought the car was going to strike him.",
#       "action": {
#         "verb": {
#           "text": "run",
#           "tense": "past"
#         },
#         "text": "had run",
#         "normalized": "have run"
#       }
#     },
#     {
#       "subject": {
#         "text": "Torres",
#         "keywords": [
#           {
#             "text": "Torres"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Person",
#             "text": "Torres"
#           }
#         ]
#       },
#       "sentence": " Coughlin said he initially thought the Jaguar had run over his partner, while Torres, who managed to dodge the car, testified he thought the car was going to strike him.",
#       "object": {
#         "text": "to dodge the car",
#         "keywords": [
#           {
#             "text": "car"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "manage",
#           "tense": "past"
#         },
#         "text": "managed",
#         "normalized": "manage"
#       }
#     },
#     {
#       "subject": {
#         "text": "Torres",
#         "keywords": [
#           {
#             "text": "Torres"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Person",
#             "text": "Torres"
#           }
#         ]
#       },
#       "sentence": " Coughlin said he initially thought the Jaguar had run over his partner, while Torres, who managed to dodge the car, testified he thought the car was going to strike him.",
#       "object": {
#         "text": "the car",
#         "keywords": [
#           {
#             "text": "car"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "dodge",
#           "tense": "future"
#         },
#         "text": "managed to dodge",
#         "normalized": "manage to dodge"
#       }
#     },
#     {
#       "subject": {
#         "text": "Diaz",
#         "keywords": [
#           {
#             "text": "Diaz"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Person",
#             "text": "Officer Jose Diaz"
#           }
#         ]
#       },
#       "sentence": " In his testimony Friday, Diaz said he and his partner had been assigned that evening shift in July 2016 to look for suspects in a child abuse case when they came across the Jaguar.",
#       "object": {
#         "text": "he and his partner had been assigned that evening shift in July 2016 to look for suspects in a child abuse case when they came across the Jaguar",
#         "keywords": [
#           {
#             "text": "child abuse case"
#           },
#           {
#             "text": "evening shift"
#           },
#           {
#             "text": "suspects"
#           },
#           {
#             "text": "Jaguar"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Person",
#             "text": "Officer Jose Diaz"
#           },
#           {
#             "type": "JobTitle",
#             "text": "partner"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "say",
#           "tense": "past"
#         },
#         "text": "said",
#         "normalized": "say"
#       }
#     },
#     {
#       "subject": {
#         "text": "for suspects",
#         "keywords": [
#           {
#             "text": "suspects"
#           }
#         ]
#       },
#       "sentence": " In his testimony Friday, Diaz said he and his partner had been assigned that evening shift in July 2016 to look for suspects in a child abuse case when they came across the Jaguar.",
#       "action": {
#         "verb": {
#           "text": "look",
#           "tense": "future"
#         },
#         "text": "to look",
#         "normalized": "to look"
#       }
#     },
#     {
#       "subject": {
#         "text": "They"
#       },
#       "sentence": " They gave chase after learning the sports car had been reported stolen but lost the vehicle in traffic.",
#       "action": {
#         "verb": {
#           "text": "give",
#           "tense": "past"
#         },
#         "text": "gave",
#         "normalized": "give"
#       }
#     },
#     {
#       "subject": {
#         "text": "They"
#       },
#       "sentence": " They gave chase after learning the sports car had been reported stolen but lost the vehicle in traffic.",
#       "object": {
#         "text": "the sports car",
#         "keywords": [
#           {
#             "text": "sports car"
#           }
#         ],
#         "entities": []
#       },
#       "action": {
#         "verb": {
#           "text": "learn",
#           "tense": "present"
#         },
#         "text": "learning",
#         "normalized": "learn"
#       }
#     },
#     {
#       "subject": {
#         "text": "They"
#       },
#       "sentence": " They gave chase after learning the sports car had been reported stolen but lost the vehicle in traffic.",
#       "object": {
#         "text": "the vehicle",
#         "keywords": [
#           {
#             "text": "vehicle"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "lose",
#           "tense": "past"
#         },
#         "text": "lost",
#         "normalized": "lose"
#       }
#     },
#     {
#       "subject": {
#         "text": "the record",
#         "keywords": [
#           {
#             "text": "record"
#           }
#         ]
#       },
#       "sentence": " \u201cThere wasn\u2019t anything in the record that would authorize him to have his firearm out of the holster, and it was a dangerous situation not only for that reason,\" he said.",
#       "object": {
#         "text": "him to have his firearm out of the holster",
#         "keywords": [
#           {
#             "text": "holster"
#           },
#           {
#             "text": "firearm"
#           }
#         ],
#         "entities": []
#       },
#       "action": {
#         "verb": {
#           "text": "authorize",
#           "tense": "future"
#         },
#         "text": "would authorize",
#         "normalized": "would authorize"
#       }
#     },
#     {
#       "subject": {
#         "text": "he",
#         "entities": []
#       },
#       "sentence": " \u201cThere wasn\u2019t anything in the record that would authorize him to have his firearm out of the holster, and it was a dangerous situation not only for that reason,\" he said.",
#       "object": {
#         "text": "There wasn\u2019t anything in the record that would authorize him to have his firearm out of the holster, and it was a dangerous situation not only for that reason",
#         "keywords": [
#           {
#             "text": "dangerous situation"
#           },
#           {
#             "text": "holster"
#           },
#           {
#             "text": "firearm"
#           },
#           {
#             "text": "reason"
#           }
#         ],
#         "entities": []
#       },
#       "action": {
#         "verb": {
#           "text": "say",
#           "tense": "past"
#         },
#         "text": "said",
#         "normalized": "say"
#       }
#     },
#     {
#       "subject": {
#         "text": "He",
#         "entities": []
#       },
#       "sentence": " \u201c\u2026 He could have discharged the weapon at himself or at his partner or anyone else in the area.\u201d",
#       "object": {
#         "text": "discharged the weapon",
#         "keywords": [
#           {
#             "text": "weapon"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "have",
#           "tense": "future"
#         },
#         "text": "have",
#         "normalized": "have"
#       }
#     },
#     {
#       "subject": {
#         "text": "He",
#         "entities": []
#       },
#       "sentence": " \u201c\u2026 He could have discharged the weapon at himself or at his partner or anyone else in the area.\u201d",
#       "object": {
#         "text": "the weapon",
#         "keywords": [
#           {
#             "text": "weapon"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "discharge",
#           "tense": "future"
#         },
#         "text": "could have discharged",
#         "normalized": "could have discharge"
#       }
#     }
#   ],
#   "retrieved_url": "https://www.chicagotribune.com/news/criminal-justice/ct-fatal-chicago-police-shooting-hearing-20190809-kmahnsrqirff5c52aqnjrgl64i-story.html",
#   "language": "en"
# }

# %% [markdown]
# ### Semantically difficult examples

# %%
url='http://www.cnbc.com/2017/05/11/caterpillar-earnings-will-beat-all-year-long-bank-of-america-says.html'

response = natural_language_understanding.analyze(
            url = url,
            features = Features(
                        #entities = EntitiesOptions(sentiment = True, emotion = True),
                        #keywords = KeywordsOptions(sentiment = True, emotion = True),
                        concepts = ConceptsOptions(limit = 50),
                        #relations = RelationsOptions(),
                        #sentiment = SentimentOptions(),
                        #semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        #emotion = EmotionOptions(),
                        #categories = CategoriesOptions()
            )).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 1037,
#     "features": 1
#   },
#   "retrieved_url": "https://www.cnbc.com/2017/05/11/caterpillar-earnings-will-beat-all-year-long-bank-of-america-says.html",
#   "language": "en",
#   "concepts": [
#     {
#       "text": "Bank of America",
#       "relevance": 0.955122,
#       "dbpedia_resource": "http://dbpedia.org/resource/Bank_of_America"
#     },
#     {
#       "text": "Merrill Lynch",
#       "relevance": 0.88865,
#       "dbpedia_resource": "http://dbpedia.org/resource/Merrill_Lynch"
#     },
#     {
#       "text": "Private banking",
#       "relevance": 0.571594,
#       "dbpedia_resource": "http://dbpedia.org/resource/Private_banking"
#     },
#     {
#       "text": "Stock",
#       "relevance": 0.551895,
#       "dbpedia_resource": "http://dbpedia.org/resource/Stock"
#     },
#     {
#       "text": "Troubled Asset Relief Program",
#       "relevance": 0.485637,
#       "dbpedia_resource": "http://dbpedia.org/resource/Troubled_Asset_Relief_Program"
#     },
#     {
#       "text": "Morgan Stanley",
#       "relevance": 0.46867,
#       "dbpedia_resource": "http://dbpedia.org/resource/Morgan_Stanley"
#     },
#     {
#       "text": "Stock market",
#       "relevance": 0.442562,
#       "dbpedia_resource": "http://dbpedia.org/resource/Stock_market"
#     },
#     {
#       "text": "Subprime mortgage crisis",
#       "relevance": 0.439713,
#       "dbpedia_resource": "http://dbpedia.org/resource/Subprime_mortgage_crisis"
#     },
#     {
#       "text": "Safeway Inc.",
#       "relevance": 0.428831,
#       "dbpedia_resource": "http://dbpedia.org/resource/Safeway_Inc."
#     }
#   ]
# }

# %%
text="Caterpillar earnings will 'beat all year long,' Bank of America says"

response = natural_language_understanding.analyze(
            text = text,
            features = Features(
                        #entities = EntitiesOptions(sentiment = True, emotion = True),
                        #keywords = KeywordsOptions(sentiment = True, emotion = True),
                        #concepts = ConceptsOptions(limit = 50),
                        #relations = RelationsOptions(),
                        #sentiment = SentimentOptions(),
                        semantic_roles = SemanticRolesOptions(entities = True, keywords = True)
                        #emotion = EmotionOptions(),
                        #categories = CategoriesOptions()
            )).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 68,
#     "features": 1
#   },
#   "semantic_roles": [
#     {
#       "subject": {
#         "text": "Caterpillar earnings",
#         "keywords": [
#           {
#             "text": "Caterpillar earnings"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Company",
#             "text": "Caterpillar"
#           }
#         ]
#       },
#       "sentence": "Caterpillar earnings will 'beat all year long,' Bank of America says",
#       "action": {
#         "verb": {
#           "text": "'beat",
#           "tense": "future"
#         },
#         "text": "will 'beat",
#         "normalized": "will 'beat"
#       }
#     },
#     {
#       "subject": {
#         "text": "Bank of America",
#         "keywords": [
#           {
#             "text": "Bank"
#           },
#           {
#             "text": "America"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Company",
#             "text": "Bank of America"
#           }
#         ]
#       },
#       "sentence": "Caterpillar earnings will 'beat all year long,' Bank of America says",
#       "object": {
#         "text": "Caterpillar earnings will 'beat all year long",
#         "keywords": [
#           {
#             "text": "Caterpillar earnings"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Company",
#             "text": "Caterpillar"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "say",
#           "tense": "present"
#         },
#         "text": "says",
#         "normalized": "say"
#       }
#     }
#   ],
#   "language": "en"
# }

# %% [markdown]
# ## Expect the explosion of data volumes

# %%
url='https://en.wikipedia.org/wiki/University_of_Chicago'

response = natural_language_understanding.analyze(
            url = url,
            features = Features(
                        entities = EntitiesOptions(sentiment = True, emotion = True),
                        keywords = KeywordsOptions(sentiment = True, emotion = True),
                        concepts = ConceptsOptions(limit = 50),
                        relations = RelationsOptions(),
                        sentiment = SentimentOptions(),
                        semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        emotion = EmotionOptions(),
                        categories = CategoriesOptions()
            )).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 5,
#     "text_characters": 50000,
#     "features": 8
#   },
#   "sentiment": {
#     "document": {
#       "score": 0.658094,
#       "label": "positive"
#     }
#   },
#   "semantic_roles": [
#     {
#       "subject": {
#         "text": "The University of Chicago (UChicago, U of C, or Chicago)",
#         "keywords": [
#           {
#             "text": "Chicago"
#           },
#           {
#             "text": "University"
#           },
#           {
#             "text": "UChicago"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "University of Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "Company",
#                 "PeriodicalPublisher",
#                 "CollegeUniversity"
#               ],
#               "name": "University of Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago"
#             }
#           },
#           {
#             "type": "Location",
#             "text": "Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ],
#               "name": "Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/Chicago"
#             }
#           }
#         ]
#       },
#       "sentence": "The University of Chicago (UChicago, U of C, or Chicago) is a private research university in Chicago, Illinois.",
#       "object": {
#         "text": "a private research university in Chicago, Illinois",
#         "keywords": [
#           {
#             "text": "private research university"
#           },
#           {
#             "text": "Chicago"
#           },
#           {
#             "text": "Illinois"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Location",
#             "text": "Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ],
#               "name": "Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/Chicago"
#             }
#           },
#           {
#             "type": "Location",
#             "text": "Illinois",
#             "disambiguation": {
#               "subtype": [
#                 "PoliticalDistrict",
#                 "AdministrativeDivision",
#                 "GovernmentalJurisdiction",
#                 "USState",
#                 "StateOrCounty"
#               ],
#               "name": "Illinois",
#               "dbpedia_resource": "http://dbpedia.org/resource/Illinois"
#             }
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "present"
#         },
#         "text": "is",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "its main campus",
#         "keywords": [
#           {
#             "text": "main campus"
#           }
#         ]
#       },
#       "sentence": " Founded in 1890, its main campus is located in Chicago's Hyde Park neighborhood.[6] It enrolled 16,445 students in Fall 2019, including 6,286 undergraduates and 10,159 graduate students.[1] The University of Chicago is ranked among the top universities in the world by major education publications.[7] [8] [9] [10]",
#       "object": {
#         "text": "located in Chicago's Hyde Park",
#         "keywords": [
#           {
#             "text": "Hyde Park"
#           },
#           {
#             "text": "Chicago"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Location",
#             "text": "Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ],
#               "name": "Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/Chicago"
#             }
#           },
#           {
#             "type": "Facility",
#             "text": "Hyde Park"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "present"
#         },
#         "text": "is",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "its main campus",
#         "keywords": [
#           {
#             "text": "main campus"
#           }
#         ]
#       },
#       "sentence": " Founded in 1890, its main campus is located in Chicago's Hyde Park neighborhood.[6] It enrolled 16,445 students in Fall 2019, including 6,286 undergraduates and 10,159 graduate students.[1] The University of Chicago is ranked among the top universities in the world by major education publications.[7] [8] [9] [10]",
#       "action": {
#         "verb": {
#           "text": "locate",
#           "tense": "past"
#         },
#         "text": "is located",
#         "normalized": "be locate"
#       }
#     },
#     {
#       "subject": {
#         "text": "It"
#       },
#       "sentence": " Founded in 1890, its main campus is located in Chicago's Hyde Park neighborhood.[6] It enrolled 16,445 students in Fall 2019, including 6,286 undergraduates and 10,159 graduate students.[1] The University of Chicago is ranked among the top universities in the world by major education publications.[7] [8] [9] [10]",
#       "object": {
#         "text": "16,445 students",
#         "keywords": [
#           {
#             "text": "students"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "enrol enroll",
#           "tense": "past"
#         },
#         "text": "enrolled",
#         "normalized": "enrol enroll"
#       }
#     },
#     {
#       "subject": {
#         "text": "6,286 undergraduates",
#         "keywords": [
#           {
#             "text": "undergraduates"
#           }
#         ]
#       },
#       "sentence": " Founded in 1890, its main campus is located in Chicago's Hyde Park neighborhood.[6] It enrolled 16,445 students in Fall 2019, including 6,286 undergraduates and 10,159 graduate students.[1] The University of Chicago is ranked among the top universities in the world by major education publications.[7] [8] [9] [10]",
#       "object": {
#         "text": "16,445 students in Fall 2019",
#         "keywords": [
#           {
#             "text": "Fall"
#           },
#           {
#             "text": "students"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "include",
#           "tense": "present"
#         },
#         "text": "including",
#         "normalized": "include"
#       }
#     },
#     {
#       "subject": {
#         "text": "6,286 undergraduates and 10,159 graduate students.[1] The University of Chicago",
#         "keywords": [
#           {
#             "text": "graduate students."
#           },
#           {
#             "text": "undergraduates"
#           },
#           {
#             "text": "University"
#           },
#           {
#             "text": "Chicago"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "University of Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "Company",
#                 "PeriodicalPublisher",
#                 "CollegeUniversity"
#               ],
#               "name": "University of Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago"
#             }
#           }
#         ]
#       },
#       "sentence": " Founded in 1890, its main campus is located in Chicago's Hyde Park neighborhood.[6] It enrolled 16,445 students in Fall 2019, including 6,286 undergraduates and 10,159 graduate students.[1] The University of Chicago is ranked among the top universities in the world by major education publications.[7] [8] [9] [10]",
#       "object": {
#         "text": "among the top universities",
#         "keywords": [
#           {
#             "text": "universities"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "rank",
#           "tense": "past"
#         },
#         "text": "is ranked",
#         "normalized": "be rank"
#       }
#     },
#     {
#       "subject": {
#         "text": "The university",
#         "keywords": [
#           {
#             "text": "university"
#           }
#         ],
#         "entities": []
#       },
#       "sentence": " The university is composed of one undergraduate college and five graduate research divisions, which contain all of the university's graduate programs and interdisciplinary committees.",
#       "object": {
#         "text": "composed of one undergraduate college and five graduate research divisions, which contain all of the university's graduate programs and interdisciplinary committees",
#         "keywords": [
#           {
#             "text": "graduate research divisions"
#           },
#           {
#             "text": "interdisciplinary committees"
#           },
#           {
#             "text": "undergraduate college"
#           },
#           {
#             "text": "graduate programs"
#           }
#         ],
#         "entities": []
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "present"
#         },
#         "text": "is",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "The university",
#         "keywords": [
#           {
#             "text": "university"
#           }
#         ],
#         "entities": []
#       },
#       "sentence": " The university is composed of one undergraduate college and five graduate research divisions, which contain all of the university's graduate programs and interdisciplinary committees.",
#       "object": {
#         "text": "of one undergraduate college and five graduate research divisions, which contain all of the university's graduate programs and interdisciplinary committees",
#         "keywords": [
#           {
#             "text": "graduate research divisions"
#           },
#           {
#             "text": "interdisciplinary committees"
#           },
#           {
#             "text": "undergraduate college"
#           },
#           {
#             "text": "graduate programs"
#           }
#         ],
#         "entities": []
#       },
#       "action": {
#         "verb": {
#           "text": "compose",
#           "tense": "past"
#         },
#         "text": "is composed",
#         "normalized": "be compose"
#       }
#     },
#     {
#       "subject": {
#         "text": "one undergraduate college and five graduate research divisions",
#         "keywords": [
#           {
#             "text": "graduate research divisions"
#           },
#           {
#             "text": "undergraduate college"
#           }
#         ]
#       },
#       "sentence": " The university is composed of one undergraduate college and five graduate research divisions, which contain all of the university's graduate programs and interdisciplinary committees.",
#       "object": {
#         "text": "all of the university's graduate programs and interdisciplinary committees",
#         "keywords": [
#           {
#             "text": "interdisciplinary committees"
#           },
#           {
#             "text": "graduate programs"
#           },
#           {
#             "text": "university"
#           }
#         ],
#         "entities": []
#       },
#       "action": {
#         "verb": {
#           "text": "contain",
#           "tense": "present"
#         },
#         "text": "contain",
#         "normalized": "contain"
#       }
#     },
#     {
#       "subject": {
#         "text": "Beyond the arts and sciences, Chicago",
#         "keywords": [
#           {
#             "text": "arts"
#           },
#           {
#             "text": "sciences"
#           },
#           {
#             "text": "Chicago"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Location",
#             "text": "Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ],
#               "name": "Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/Chicago"
#             }
#           }
#         ]
#       },
#       "sentence": " Beyond the arts and sciences, Chicago is well known for its professional schools, which include the Pritzker School of Medicine, the Booth School of Business, the Law School, the School of Social Service Administration, the Harris School of Public Policy, the Divinity School and the Graham School of Continuing Liberal and Professional Studies, as well as the recently launched Pritzker School of Molecular Engineering.",
#       "object": {
#         "text": "well known for its professional schools, which include the Pritzker School of Medicine, the Booth School of Business, the Law School, the School of Social Service Administration, the Harris School of Public Policy, the Divinity School and the Graham School of Continuing Liberal and Professional Studies, as well as the recently launched Pritzker School of Molecular Engineering",
#         "keywords": [
#           {
#             "text": "Pritzker School"
#           },
#           {
#             "text": "Social Service Administration"
#           },
#           {
#             "text": "Continuing Liberal"
#           },
#           {
#             "text": "Booth School"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "Pritzker School of Medicine",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "CollegeUniversity",
#                 "University"
#               ],
#               "name": "Pritzker School of Medicine",
#               "dbpedia_resource": "http://dbpedia.org/resource/Pritzker_School_of_Medicine"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Booth School of Business",
#             "disambiguation": {
#               "subtype": [],
#               "name": "Booth School of Business",
#               "dbpedia_resource": "http://dbpedia.org/resource/Booth_School_of_Business"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "School of Social Service Administration",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "CollegeUniversity",
#                 "University"
#               ],
#               "name": "University of Chicago School of Social Service Administration",
#               "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago_School_of_Social_Service_Administration"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Harris School of Public Policy",
#             "disambiguation": {
#               "subtype": [
#                 "University"
#               ],
#               "name": "Harris School of Public Policy Studies",
#               "dbpedia_resource": "http://dbpedia.org/resource/Harris_School_of_Public_Policy_Studies"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Divinity School",
#             "disambiguation": {
#               "subtype": [
#                 "CollegeUniversity",
#                 "Company",
#                 "University"
#               ],
#               "name": "University of Chicago Divinity School",
#               "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago_Divinity_School"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Graham School of Continuing Liberal"
#           },
#           {
#             "type": "Organization",
#             "text": "Pritzker School of Molecular Engineering"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "present"
#         },
#         "text": "is",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "Beyond the arts and sciences, Chicago",
#         "keywords": [
#           {
#             "text": "arts"
#           },
#           {
#             "text": "sciences"
#           },
#           {
#             "text": "Chicago"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Location",
#             "text": "Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ],
#               "name": "Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/Chicago"
#             }
#           }
#         ]
#       },
#       "sentence": " Beyond the arts and sciences, Chicago is well known for its professional schools, which include the Pritzker School of Medicine, the Booth School of Business, the Law School, the School of Social Service Administration, the Harris School of Public Policy, the Divinity School and the Graham School of Continuing Liberal and Professional Studies, as well as the recently launched Pritzker School of Molecular Engineering.",
#       "object": {
#         "text": "for its professional schools, which include the Pritzker School of Medicine, the Booth School of Business, the Law School, the School of Social Service Administration, the Harris School of Public Policy, the Divinity School and the Graham School of Continuing Liberal and Professional Studies",
#         "keywords": [
#           {
#             "text": "Social Service Administration"
#           },
#           {
#             "text": "Pritzker School"
#           },
#           {
#             "text": "Continuing Liberal"
#           },
#           {
#             "text": "Booth School"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "Pritzker School of Medicine",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "CollegeUniversity",
#                 "University"
#               ],
#               "name": "Pritzker School of Medicine",
#               "dbpedia_resource": "http://dbpedia.org/resource/Pritzker_School_of_Medicine"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Booth School of Business",
#             "disambiguation": {
#               "subtype": [],
#               "name": "Booth School of Business",
#               "dbpedia_resource": "http://dbpedia.org/resource/Booth_School_of_Business"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "School of Social Service Administration",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "CollegeUniversity",
#                 "University"
#               ],
#               "name": "University of Chicago School of Social Service Administration",
#               "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago_School_of_Social_Service_Administration"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Harris School of Public Policy",
#             "disambiguation": {
#               "subtype": [
#                 "University"
#               ],
#               "name": "Harris School of Public Policy Studies",
#               "dbpedia_resource": "http://dbpedia.org/resource/Harris_School_of_Public_Policy_Studies"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Divinity School",
#             "disambiguation": {
#               "subtype": [
#                 "CollegeUniversity",
#                 "Company",
#                 "University"
#               ],
#               "name": "University of Chicago Divinity School",
#               "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago_Divinity_School"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Graham School of Continuing Liberal"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "know",
#           "tense": "past"
#         },
#         "text": "known",
#         "normalized": "know"
#       }
#     },
#     {
#       "subject": {
#         "text": "the Pritzker School of Medicine, the Booth School of Business, the Law School, the School of Social Service Administration, the Harris School of Public Policy, the Divinity School and the Graham School of Continuing Liberal and Professional Studies, as well as the recently launched Pritzker School of Molecular Engineering",
#         "keywords": [
#           {
#             "text": "Pritzker School"
#           },
#           {
#             "text": "Social Service Administration"
#           },
#           {
#             "text": "Continuing Liberal"
#           },
#           {
#             "text": "Booth School"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "Pritzker School of Medicine",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "CollegeUniversity",
#                 "University"
#               ],
#               "name": "Pritzker School of Medicine",
#               "dbpedia_resource": "http://dbpedia.org/resource/Pritzker_School_of_Medicine"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Booth School of Business",
#             "disambiguation": {
#               "subtype": [],
#               "name": "Booth School of Business",
#               "dbpedia_resource": "http://dbpedia.org/resource/Booth_School_of_Business"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "School of Social Service Administration",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "CollegeUniversity",
#                 "University"
#               ],
#               "name": "University of Chicago School of Social Service Administration",
#               "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago_School_of_Social_Service_Administration"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Harris School of Public Policy",
#             "disambiguation": {
#               "subtype": [
#                 "University"
#               ],
#               "name": "Harris School of Public Policy Studies",
#               "dbpedia_resource": "http://dbpedia.org/resource/Harris_School_of_Public_Policy_Studies"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Divinity School",
#             "disambiguation": {
#               "subtype": [
#                 "CollegeUniversity",
#                 "Company",
#                 "University"
#               ],
#               "name": "University of Chicago Divinity School",
#               "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago_Divinity_School"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Graham School of Continuing Liberal"
#           },
#           {
#             "type": "Organization",
#             "text": "Pritzker School of Molecular Engineering"
#           }
#         ]
#       },
#       "sentence": " Beyond the arts and sciences, Chicago is well known for its professional schools, which include the Pritzker School of Medicine, the Booth School of Business, the Law School, the School of Social Service Administration, the Harris School of Public Policy, the Divinity School and the Graham School of Continuing Liberal and Professional Studies, as well as the recently launched Pritzker School of Molecular Engineering.",
#       "object": {
#         "text": "its professional schools",
#         "keywords": [
#           {
#             "text": "professional schools"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "include",
#           "tense": "present"
#         },
#         "text": "include",
#         "normalized": "include"
#       }
#     },
#     {
#       "subject": {
#         "text": "Pritzker School of Molecular Engineering",
#         "keywords": [
#           {
#             "text": "Pritzker School"
#           },
#           {
#             "text": "Molecular Engineering"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "Pritzker School of Molecular Engineering"
#           }
#         ]
#       },
#       "sentence": " Beyond the arts and sciences, Chicago is well known for its professional schools, which include the Pritzker School of Medicine, the Booth School of Business, the Law School, the School of Social Service Administration, the Harris School of Public Policy, the Divinity School and the Graham School of Continuing Liberal and Professional Studies, as well as the recently launched Pritzker School of Molecular Engineering.",
#       "action": {
#         "verb": {
#           "text": "launch",
#           "tense": "past"
#         },
#         "text": "launched",
#         "normalized": "launch"
#       }
#     },
#     {
#       "subject": {
#         "text": "The university",
#         "keywords": [
#           {
#             "text": "university"
#           }
#         ],
#         "entities": []
#       },
#       "sentence": " The university has additional campuses and centers in London, Paris, Beijing, Delhi, and Hong Kong, as well as in downtown Chicago.[11] [12]",
#       "object": {
#         "text": "additional campuses and centers",
#         "keywords": [
#           {
#             "text": "additional campuses"
#           },
#           {
#             "text": "centers"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "Gerald Ratner Athletics Center"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "have",
#           "tense": "present"
#         },
#         "text": "has",
#         "normalized": "have"
#       }
#     },
#     {
#       "subject": {
#         "text": "The University of Chicago",
#         "keywords": [
#           {
#             "text": "University"
#           },
#           {
#             "text": "Chicago"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "University of Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "Company",
#                 "PeriodicalPublisher",
#                 "CollegeUniversity"
#               ],
#               "name": "University of Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago"
#             }
#           }
#         ]
#       },
#       "sentence": " The University of Chicago was incorporated as a coeducational [29] :137 institution in 1890 by the American Baptist Education Society, using $400,000 donated to the ABES to match a $600,000 donation from Baptist oil magnate and philanthropist John D. Rockefeller,[30] and including land donated by Marshall Field.[31] While the Rockefeller donation provided money for academic operations and long-term endowment, it was stipulated that such money could not be used for buildings.",
#       "object": {
#         "text": "incorporated"
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "past"
#         },
#         "text": "was",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "$400,000 donated to the ABES",
#         "keywords": [
#           {
#             "text": "ABES"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Quantity",
#             "text": "$400,000"
#           }
#         ]
#       },
#       "sentence": " The University of Chicago was incorporated as a coeducational [29] :137 institution in 1890 by the American Baptist Education Society, using $400,000 donated to the ABES to match a $600,000 donation from Baptist oil magnate and philanthropist John D. Rockefeller,[30] and including land donated by Marshall Field.[31] While the Rockefeller donation provided money for academic operations and long-term endowment, it was stipulated that such money could not be used for buildings.",
#       "object": {
#         "text": "to match a $600,000 donation from Baptist oil magnate and philanthropist",
#         "keywords": [
#           {
#             "text": "Baptist oil magnate"
#           },
#           {
#             "text": "philanthropist"
#           },
#           {
#             "text": "donation"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Company",
#             "text": "Baptist oil"
#           },
#           {
#             "type": "Quantity",
#             "text": "$600,000"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "use",
#           "tense": "present"
#         },
#         "text": "using",
#         "normalized": "use"
#       }
#     },
#     {
#       "subject": {
#         "text": "$400,000",
#         "entities": [
#           {
#             "type": "Quantity",
#             "text": "$400,000"
#           }
#         ]
#       },
#       "sentence": " The University of Chicago was incorporated as a coeducational [29] :137 institution in 1890 by the American Baptist Education Society, using $400,000 donated to the ABES to match a $600,000 donation from Baptist oil magnate and philanthropist John D. Rockefeller,[30] and including land donated by Marshall Field.[31] While the Rockefeller donation provided money for academic operations and long-term endowment, it was stipulated that such money could not be used for buildings.",
#       "object": {
#         "text": "to the ABES",
#         "keywords": [
#           {
#             "text": "ABES"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "donate",
#           "tense": "past"
#         },
#         "text": "donated",
#         "normalized": "donate"
#       }
#     },
#     {
#       "subject": {
#         "text": "by Marshall Field.",
#         "keywords": [
#           {
#             "text": "Marshall Field"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Facility",
#             "text": "Marshall Field."
#           }
#         ]
#       },
#       "sentence": " The University of Chicago was incorporated as a coeducational [29] :137 institution in 1890 by the American Baptist Education Society, using $400,000 donated to the ABES to match a $600,000 donation from Baptist oil magnate and philanthropist John D. Rockefeller,[30] and including land donated by Marshall Field.[31] While the Rockefeller donation provided money for academic operations and long-term endowment, it was stipulated that such money could not be used for buildings.",
#       "object": {
#         "text": "land",
#         "keywords": [
#           {
#             "text": "land"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "donate",
#           "tense": "past"
#         },
#         "text": "donated",
#         "normalized": "donate"
#       }
#     },
#     {
#       "subject": {
#         "text": "the Rockefeller donation",
#         "keywords": [
#           {
#             "text": "Rockefeller donation"
#           }
#         ]
#       },
#       "sentence": " The University of Chicago was incorporated as a coeducational [29] :137 institution in 1890 by the American Baptist Education Society, using $400,000 donated to the ABES to match a $600,000 donation from Baptist oil magnate and philanthropist John D. Rockefeller,[30] and including land donated by Marshall Field.[31] While the Rockefeller donation provided money for academic operations and long-term endowment, it was stipulated that such money could not be used for buildings.",
#       "object": {
#         "text": "money",
#         "keywords": [
#           {
#             "text": "money"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "provide",
#           "tense": "past"
#         },
#         "text": "provided",
#         "normalized": "provide"
#       }
#     },
#     {
#       "subject": {
#         "text": "it"
#       },
#       "sentence": " The University of Chicago was incorporated as a coeducational [29] :137 institution in 1890 by the American Baptist Education Society, using $400,000 donated to the ABES to match a $600,000 donation from Baptist oil magnate and philanthropist John D. Rockefeller,[30] and including land donated by Marshall Field.[31] While the Rockefeller donation provided money for academic operations and long-term endowment, it was stipulated that such money could not be used for buildings.",
#       "object": {
#         "text": "stipulated that such money could not be used for buildings",
#         "keywords": [
#           {
#             "text": "money"
#           },
#           {
#             "text": "buildings"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Facility",
#             "text": "Classics Building"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "past"
#         },
#         "text": "was",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "it"
#       },
#       "sentence": " The University of Chicago was incorporated as a coeducational [29] :137 institution in 1890 by the American Baptist Education Society, using $400,000 donated to the ABES to match a $600,000 donation from Baptist oil magnate and philanthropist John D. Rockefeller,[30] and including land donated by Marshall Field.[31] While the Rockefeller donation provided money for academic operations and long-term endowment, it was stipulated that such money could not be used for buildings.",
#       "object": {
#         "text": "that such money could not be used for buildings",
#         "keywords": [
#           {
#             "text": "money"
#           },
#           {
#             "text": "buildings"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Facility",
#             "text": "Classics Building"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "stipulate",
#           "tense": "past"
#         },
#         "text": "was stipulated",
#         "normalized": "be stipulate"
#       }
#     },
#     {
#       "subject": {
#         "text": "The Hyde Park campus",
#         "keywords": [
#           {
#             "text": "Hyde Park campus"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Facility",
#             "text": "Hyde Park"
#           }
#         ]
#       },
#       "sentence": " The Hyde Park campus was financed by donations from wealthy Chicagoans like Silas B. Cobb who provided the funds for the campus' first building, Cobb Lecture Hall, and matched Marshall Field's pledge of $100,000.",
#       "object": {
#         "text": "financed by donations from wealthy Chicagoans like Silas B. Cobb who provided the funds for the campus' first building, Cobb Lecture Hall, and matched Marshall Field's pledge of $100,000",
#         "keywords": [
#           {
#             "text": "Silas B. Cobb"
#           },
#           {
#             "text": "Cobb Lecture Hall"
#           },
#           {
#             "text": "wealthy Chicagoans"
#           },
#           {
#             "text": "Marshall Field"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Person",
#             "text": "Silas B. Cobb"
#           },
#           {
#             "type": "Facility",
#             "text": "Christ Church Hall."
#           },
#           {
#             "type": "Facility",
#             "text": "Cobb Lecture Hall"
#           },
#           {
#             "type": "Person",
#             "text": "Marshall Field",
#             "disambiguation": {
#               "subtype": [
#                 "CompanyFounder"
#               ],
#               "name": "Marshall Field",
#               "dbpedia_resource": "http://dbpedia.org/resource/Marshall_Field"
#             }
#           },
#           {
#             "type": "Quantity",
#             "text": "$100,000"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "past"
#         },
#         "text": "was",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "The Hyde Park campus",
#         "keywords": [
#           {
#             "text": "Hyde Park campus"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Facility",
#             "text": "Hyde Park"
#           }
#         ]
#       },
#       "sentence": " The Hyde Park campus was financed by donations from wealthy Chicagoans like Silas B. Cobb who provided the funds for the campus' first building, Cobb Lecture Hall, and matched Marshall Field's pledge of $100,000.",
#       "object": {
#         "text": "by donations from wealthy Chicagoans like Silas B. Cobb who provided the funds for the campus' first building, Cobb Lecture Hall, and matched Marshall Field's pledge of $100,000",
#         "keywords": [
#           {
#             "text": "Silas B. Cobb"
#           },
#           {
#             "text": "Cobb Lecture Hall"
#           },
#           {
#             "text": "wealthy Chicagoans"
#           },
#           {
#             "text": "Marshall Field"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Person",
#             "text": "Silas B. Cobb"
#           },
#           {
#             "type": "Facility",
#             "text": "Christ Church Hall."
#           },
#           {
#             "type": "Facility",
#             "text": "Cobb Lecture Hall"
#           },
#           {
#             "type": "Person",
#             "text": "Marshall Field",
#             "disambiguation": {
#               "subtype": [
#                 "CompanyFounder"
#               ],
#               "name": "Marshall Field",
#               "dbpedia_resource": "http://dbpedia.org/resource/Marshall_Field"
#             }
#           },
#           {
#             "type": "Quantity",
#             "text": "$100,000"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "finance",
#           "tense": "past"
#         },
#         "text": "was financed",
#         "normalized": "be finance"
#       }
#     },
#     {
#       "subject": {
#         "text": "the funds",
#         "keywords": [
#           {
#             "text": "funds"
#           }
#         ]
#       },
#       "sentence": " The Hyde Park campus was financed by donations from wealthy Chicagoans like Silas B. Cobb who provided the funds for the campus' first building, Cobb Lecture Hall, and matched Marshall Field's pledge of $100,000.",
#       "object": {
#         "text": "for the campus' first building",
#         "keywords": [
#           {
#             "text": "campus"
#           },
#           {
#             "text": "building"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Facility",
#             "text": "Christ Church Hall."
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "provide",
#           "tense": "past"
#         },
#         "text": "provided",
#         "normalized": "provide"
#       }
#     },
#     {
#       "subject": {
#         "text": "businessmen Charles L. Hutchinson (trustee, treasurer and donor of Hutchinson Commons), Martin A. Ryerson (president of the board of trustees and donor of the Ryerson Physical Laboratory) Adolphus Clay Bartlett and Leon Mandel, who funded the construction of the gymnasium and assembly hall, and George C. Walker of the Walker Museum, a relative of Cobb who encouraged his inaugural donation for facilities.[32]",
#         "keywords": [
#           {
#             "text": "Martin A. Ryerson"
#           },
#           {
#             "text": "Ryerson Physical Laboratory"
#           },
#           {
#             "text": "Charles L. Hutchinson"
#           },
#           {
#             "text": "Adolphus Clay Bartlett"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Person",
#             "text": "Charles L. Hutchinson"
#           },
#           {
#             "type": "JobTitle",
#             "text": "trustee"
#           },
#           {
#             "type": "JobTitle",
#             "text": "treasurer"
#           },
#           {
#             "type": "Organization",
#             "text": "Hutchinson Commons"
#           },
#           {
#             "type": "Person",
#             "text": "Martin A. Ryerson"
#           },
#           {
#             "type": "JobTitle",
#             "text": "president of the board"
#           },
#           {
#             "type": "Facility",
#             "text": "Ryerson Physical Laboratory"
#           },
#           {
#             "type": "Person",
#             "text": "Adolphus Clay Bartlett"
#           },
#           {
#             "type": "Person",
#             "text": "Leon Mandel"
#           },
#           {
#             "type": "Facility",
#             "text": "assembly hall"
#           },
#           {
#             "type": "Person",
#             "text": "George C. Walker"
#           },
#           {
#             "type": "Facility",
#             "text": "Walker Museum"
#           },
#           {
#             "type": "Person",
#             "text": "Silas B. Cobb"
#           }
#         ]
#       },
#       "sentence": " Other early benefactors included businessmen Charles L. Hutchinson (trustee, treasurer and donor of Hutchinson Commons), Martin A. Ryerson (president of the board of trustees and donor of the Ryerson Physical Laboratory) Adolphus Clay Bartlett and Leon Mandel, who funded the construction of the gymnasium and assembly hall, and George C. Walker of the Walker Museum, a relative of Cobb who encouraged his inaugural donation for facilities.[32]",
#       "object": {
#         "text": "Other early benefactors",
#         "keywords": [
#           {
#             "text": "early benefactors"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "include",
#           "tense": "past"
#         },
#         "text": "included",
#         "normalized": "include"
#       }
#     },
#     {
#       "subject": {
#         "text": "Adolphus Clay Bartlett and Leon Mandel",
#         "keywords": [
#           {
#             "text": "Adolphus Clay Bartlett"
#           },
#           {
#             "text": "Leon Mandel"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Person",
#             "text": "Adolphus Clay Bartlett"
#           },
#           {
#             "type": "Person",
#             "text": "Leon Mandel"
#           }
#         ]
#       },
#       "sentence": " Other early benefactors included businessmen Charles L. Hutchinson (trustee, treasurer and donor of Hutchinson Commons), Martin A. Ryerson (president of the board of trustees and donor of the Ryerson Physical Laboratory) Adolphus Clay Bartlett and Leon Mandel, who funded the construction of the gymnasium and assembly hall, and George C. Walker of the Walker Museum, a relative of Cobb who encouraged his inaugural donation for facilities.[32]",
#       "object": {
#         "text": "the construction of the gymnasium",
#         "keywords": [
#           {
#             "text": "gymnasium"
#           },
#           {
#             "text": "construction"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "fund",
#           "tense": "past"
#         },
#         "text": "funded",
#         "normalized": "fund"
#       }
#     },
#     {
#       "subject": {
#         "text": "The Hyde Park campus",
#         "keywords": [
#           {
#             "text": "Hyde Park campus"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Facility",
#             "text": "Hyde Park"
#           }
#         ]
#       },
#       "sentence": " The Hyde Park campus continued the legacy of the original university of the same name, which had closed in the 1880s after its campus was foreclosed on.[33] What became known as the Old University of Chicago had been founded by a small group of Baptist educators in 1856 through a land endowment from Senator Stephen A. Douglas.",
#       "object": {
#         "text": "the legacy of the original university of the same name, which had closed in the 1880s after its campus was foreclosed on.[33] What became known as the Old University of Chicago had been founded by a small group of Baptist educators in 1856 through a land endowment from Senator Stephen A. Douglas",
#         "keywords": [
#           {
#             "text": "Senator Stephen A."
#           },
#           {
#             "text": "land endowment"
#           },
#           {
#             "text": "Baptist educators"
#           },
#           {
#             "text": "small group"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "Old University of Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "CollegeUniversity"
#               ],
#               "name": "Old University of Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/Old_University_of_Chicago"
#             }
#           },
#           {
#             "type": "Person",
#             "text": "Senator Stephen A. Douglas",
#             "disambiguation": {
#               "subtype": [
#                 "Politician",
#                 "U.S.Congressperson"
#               ],
#               "name": "Stephen A. Douglas",
#               "dbpedia_resource": "http://dbpedia.org/resource/Stephen_A._Douglas"
#             }
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "continue",
#           "tense": "past"
#         },
#         "text": "continued",
#         "normalized": "continue"
#       }
#     },
#     {
#       "subject": {
#         "text": "the Old University of Chicago",
#         "keywords": [
#           {
#             "text": "Old University"
#           },
#           {
#             "text": "Chicago"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "Old University of Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "CollegeUniversity"
#               ],
#               "name": "Old University of Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/Old_University_of_Chicago"
#             }
#           }
#         ]
#       },
#       "sentence": " The Hyde Park campus continued the legacy of the original university of the same name, which had closed in the 1880s after its campus was foreclosed on.[33] What became known as the Old University of Chicago had been founded by a small group of Baptist educators in 1856 through a land endowment from Senator Stephen A. Douglas.",
#       "object": {
#         "text": "founded by a small group of Baptist educators",
#         "keywords": [
#           {
#             "text": "Baptist educators"
#           },
#           {
#             "text": "small group"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "past"
#         },
#         "text": "been",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "by a small group of Baptist educators",
#         "keywords": [
#           {
#             "text": "Baptist educators"
#           },
#           {
#             "text": "small group"
#           }
#         ]
#       },
#       "sentence": " The Hyde Park campus continued the legacy of the original university of the same name, which had closed in the 1880s after its campus was foreclosed on.[33] What became known as the Old University of Chicago had been founded by a small group of Baptist educators in 1856 through a land endowment from Senator Stephen A. Douglas.",
#       "object": {
#         "text": "the Old University of Chicago",
#         "keywords": [
#           {
#             "text": "Old University"
#           },
#           {
#             "text": "Chicago"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "Old University of Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "CollegeUniversity"
#               ],
#               "name": "Old University of Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/Old_University_of_Chicago"
#             }
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "found",
#           "tense": "past"
#         },
#         "text": "had been founded",
#         "normalized": "have be found"
#       }
#     },
#     {
#       "subject": {
#         "text": "These connections",
#         "keywords": [
#           {
#             "text": "connections"
#           }
#         ]
#       },
# ...
#       "relevance": 0.081404,
#       "emotion": {
#         "sadness": 0.052751,
#         "joy": 0.092349,
#         "fear": 0.107148,
#         "disgust": 0.117039,
#         "anger": 0.089242
#       },
#       "count": 1,
#       "confidence": 0.304563
#     },
#     {
#       "type": "Organization",
#       "text": "Obama Foundation",
#       "sentiment": {
#         "score": -0.406694,
#         "label": "negative"
#       },
#       "relevance": 0.081173,
#       "emotion": {
#         "sadness": 0.052751,
#         "joy": 0.092349,
#         "fear": 0.107148,
#         "disgust": 0.117039,
#         "anger": 0.089242
#       },
#       "count": 1,
#       "confidence": 0.943334
#     },
#     {
#       "type": "Organization",
#       "text": "American Baptist Education Society",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.080143,
#       "emotion": {
#         "sadness": 0.135188,
#         "joy": 0.132905,
#         "fear": 0.026234,
#         "disgust": 0.059362,
#         "anger": 0.026427
#       },
#       "count": 1,
#       "confidence": 0.864947
#     },
#     {
#       "type": "Quantity",
#       "text": "$400,000",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.080095,
#       "emotion": {
#         "sadness": 0.135188,
#         "joy": 0.132905,
#         "fear": 0.026234,
#         "disgust": 0.059362,
#         "anger": 0.026427
#       },
#       "count": 1,
#       "confidence": 0.8
#     },
#     {
#       "type": "Organization",
#       "text": "ICCA",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.080059,
#       "emotion": {
#         "sadness": 0.108129,
#         "joy": 0.670762,
#         "fear": 0.071377,
#         "disgust": 0.011867,
#         "anger": 0.100176
#       },
#       "disambiguation": {
#         "subtype": [
#           "MusicalGroup",
#           "MusicalArtist"
#         ],
#         "name": "Cappella",
#         "dbpedia_resource": "http://dbpedia.org/resource/Cappella"
#       },
#       "count": 3,
#       "confidence": 0.999735
#     },
#     {
#       "type": "Quantity",
#       "text": "$600,000",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.080029,
#       "emotion": {
#         "sadness": 0.135188,
#         "joy": 0.132905,
#         "fear": 0.026234,
#         "disgust": 0.059362,
#         "anger": 0.026427
#       },
#       "count": 1,
#       "confidence": 0.8
#     },
#     {
#       "type": "Person",
#       "text": "Silas B. Cobb",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.079405,
#       "emotion": {
#         "sadness": 0.030324,
#         "joy": 0.451096,
#         "fear": 0.021903,
#         "disgust": 0.247523,
#         "anger": 0.140633
#       },
#       "count": 1,
#       "confidence": 0.95779
#     },
#     {
#       "type": "Facility",
#       "text": "Cobb Lecture Hall",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.079288,
#       "emotion": {
#         "sadness": 0.030324,
#         "joy": 0.451096,
#         "fear": 0.021903,
#         "disgust": 0.247523,
#         "anger": 0.140633
#       },
#       "count": 1,
#       "confidence": 0.574608
#     },
#     {
#       "type": "Quantity",
#       "text": "$100,000",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.0792,
#       "emotion": {
#         "sadness": 0.030324,
#         "joy": 0.451096,
#         "fear": 0.021903,
#         "disgust": 0.247523,
#         "anger": 0.140633
#       },
#       "count": 1,
#       "confidence": 0.8
#     },
#     {
#       "type": "Person",
#       "text": "Charles L. Hutchinson",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.079098,
#       "emotion": {
#         "sadness": 0.019468,
#         "joy": 0.399881,
#         "fear": 0.025578,
#         "disgust": 0.165723,
#         "anger": 0.061522
#       },
#       "count": 1,
#       "confidence": 0.995643
#     },
#     {
#       "type": "Organization",
#       "text": "Hutchinson Commons",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.07901,
#       "emotion": {
#         "sadness": 0.019468,
#         "joy": 0.399881,
#         "fear": 0.025578,
#         "disgust": 0.165723,
#         "anger": 0.061522
#       },
#       "count": 1,
#       "confidence": 0.436487
#     },
#     {
#       "type": "Person",
#       "text": "Martin A. Ryerson",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.078976,
#       "emotion": {
#         "sadness": 0.019468,
#         "joy": 0.399881,
#         "fear": 0.025578,
#         "disgust": 0.165723,
#         "anger": 0.061522
#       },
#       "count": 1,
#       "confidence": 0.991064
#     },
#     {
#       "type": "Facility",
#       "text": "Ryerson Physical Laboratory",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.07885,
#       "emotion": {
#         "sadness": 0.019468,
#         "joy": 0.399881,
#         "fear": 0.025578,
#         "disgust": 0.165723,
#         "anger": 0.061522
#       },
#       "count": 1,
#       "confidence": 0.538464
#     },
#     {
#       "type": "Person",
#       "text": "Adolphus Clay Bartlett",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.078806,
#       "emotion": {
#         "sadness": 0.019468,
#         "joy": 0.399881,
#         "fear": 0.025578,
#         "disgust": 0.165723,
#         "anger": 0.061522
#       },
#       "count": 1,
#       "confidence": 0.656795
#     },
#     {
#       "type": "Person",
#       "text": "Leon Mandel",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.078771,
#       "emotion": {
#         "sadness": 0.019468,
#         "joy": 0.399881,
#         "fear": 0.025578,
#         "disgust": 0.165723,
#         "anger": 0.061522
#       },
#       "count": 1,
#       "confidence": 0.88734
#     },
#     {
#       "type": "Person",
#       "text": "George C. Walker",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.078633,
#       "emotion": {
#         "sadness": 0.019468,
#         "joy": 0.399881,
#         "fear": 0.025578,
#         "disgust": 0.165723,
#         "anger": 0.061522
#       },
#       "count": 1,
#       "confidence": 0.976952
#     },
#     {
#       "type": "Organization",
#       "text": "National Panhellenic Conference",
#       "sentiment": {
#         "score": 0.581016,
#         "label": "positive"
#       },
#       "relevance": 0.023348,
#       "emotion": {
#         "sadness": 0.249341,
#         "joy": 0.247668,
#         "fear": 0.054983,
#         "disgust": 0.211973,
#         "anger": 0.089892
#       },
#       "disambiguation": {
#         "name": "National_Panhellenic_Conference",
#         "dbpedia_resource": "http://dbpedia.org/resource/National_Panhellenic_Conference"
#       },
#       "count": 1,
#       "confidence": 0.492635
#     },
#     {
#       "type": "Location",
#       "text": "pa",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "emotion": {
#         "sadness": 0.040133,
#         "joy": 0.369032,
#         "fear": 0.017951,
#         "disgust": 0.062488,
#         "anger": 0.103565
#       },
#       "count": 1,
#       "confidence": 0.928223
#     }
#   ],
#   "emotion": {
#     "document": {
#       "emotion": {
#         "sadness": 0.14372,
#         "joy": 0.554724,
#         "fear": 0.0658,
#         "disgust": 0.104112,
#         "anger": 0.072885
#       }
#     }
#   },
#   "concepts": [
#     {
#       "text": "University of Chicago",
#       "relevance": 0.878481,
#       "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago"
#     },
#     {
#       "text": "Chicago",
#       "relevance": 0.25908,
#       "dbpedia_resource": "http://dbpedia.org/resource/Chicago"
#     },
#     {
#       "text": "Hyde Park, Chicago",
#       "relevance": 0.185555,
#       "dbpedia_resource": "http://dbpedia.org/resource/Hyde_Park,_Chicago"
#     },
#     {
#       "text": "Association of American Universities",
#       "relevance": 0.169816,
#       "dbpedia_resource": "http://dbpedia.org/resource/Association_of_American_Universities"
#     },
#     {
#       "text": "National Association of Independent Colleges and Universities",
#       "relevance": 0.15709,
#       "dbpedia_resource": "http://dbpedia.org/resource/National_Association_of_Independent_Colleges_and_Universities"
#     },
#     {
#       "text": "College",
#       "relevance": 0.154596,
#       "dbpedia_resource": "http://dbpedia.org/resource/College"
#     },
#     {
#       "text": "Nobel Prize",
#       "relevance": 0.152689,
#       "dbpedia_resource": "http://dbpedia.org/resource/Nobel_Prize"
#     },
#     {
#       "text": "Argonne National Laboratory",
#       "relevance": 0.152649,
#       "dbpedia_resource": "http://dbpedia.org/resource/Argonne_National_Laboratory"
#     },
#     {
#       "text": "University of Chicago Booth School of Business",
#       "relevance": 0.145025,
#       "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago_Booth_School_of_Business"
#     },
#     {
#       "text": "University",
#       "relevance": 0.137912,
#       "dbpedia_resource": "http://dbpedia.org/resource/University"
#     },
#     {
#       "text": "Chicago Maroons",
#       "relevance": 0.136262,
#       "dbpedia_resource": "http://dbpedia.org/resource/Chicago_Maroons"
#     },
#     {
#       "text": "Illinois",
#       "relevance": 0.134034,
#       "dbpedia_resource": "http://dbpedia.org/resource/Illinois"
#     },
#     {
#       "text": "Ivy League",
#       "relevance": 0.132047,
#       "dbpedia_resource": "http://dbpedia.org/resource/Ivy_League"
#     },
#     {
#       "text": "University of Chicago Law School",
#       "relevance": 0.128186,
#       "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago_Law_School"
#     },
#     {
#       "text": "Doctorate",
#       "relevance": 0.127362,
#       "dbpedia_resource": "http://dbpedia.org/resource/Doctorate"
#     },
#     {
#       "text": "North-American Interfraternity Conference",
#       "relevance": 0.126691,
#       "dbpedia_resource": "http://dbpedia.org/resource/North-American_Interfraternity_Conference"
#     },
#     {
#       "text": "Big Ten Conference",
#       "relevance": 0.125545,
#       "dbpedia_resource": "http://dbpedia.org/resource/Big_Ten_Conference"
#     },
#     {
#       "text": "Rector",
#       "relevance": 0.124455,
#       "dbpedia_resource": "http://dbpedia.org/resource/Rector"
#     },
#     {
#       "text": "Barack Obama",
#       "relevance": 0.122831,
#       "dbpedia_resource": "http://dbpedia.org/resource/Barack_Obama"
#     },
#     {
#       "text": "South Campus Residence Hall",
#       "relevance": 0.121568,
#       "dbpedia_resource": "http://dbpedia.org/resource/South_Campus_Residence_Hall"
#     },
#     {
#       "text": "University of Chicago Divinity School",
#       "relevance": 0.120536,
#       "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago_Divinity_School"
#     },
#     {
#       "text": "University of Chicago Scavenger Hunt",
#       "relevance": 0.116811,
#       "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago_Scavenger_Hunt"
#     },
#     {
#       "text": "The Chicago Maroon",
#       "relevance": 0.115214,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Chicago_Maroon"
#     },
#     {
#       "text": "Enrico Fermi",
#       "relevance": 0.114747,
#       "dbpedia_resource": "http://dbpedia.org/resource/Enrico_Fermi"
#     },
#     {
#       "text": "University Athletic Association",
#       "relevance": 0.112454,
#       "dbpedia_resource": "http://dbpedia.org/resource/University_Athletic_Association"
#     },
#     {
#       "text": "University of Cambridge",
#       "relevance": 0.108563,
#       "dbpedia_resource": "http://dbpedia.org/resource/University_of_Cambridge"
#     },
#     {
#       "text": "Chancellor",
#       "relevance": 0.107194,
#       "dbpedia_resource": "http://dbpedia.org/resource/Chancellor_(education)"
#     },
#     {
#       "text": "Yale University",
#       "relevance": 0.106928,
#       "dbpedia_resource": "http://dbpedia.org/resource/Yale_University"
#     },
#     {
#       "text": "University of Chicago Laboratory Schools",
#       "relevance": 0.105102,
#       "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago_Laboratory_Schools"
#     },
#     {
#       "text": "Northwestern University",
#       "relevance": 0.105068,
#       "dbpedia_resource": "http://dbpedia.org/resource/Northwestern_University"
#     },
#     {
#       "text": "Fraternities and sororities",
#       "relevance": 0.103901,
#       "dbpedia_resource": "http://dbpedia.org/resource/Fraternities_and_sororities"
#     },
#     {
#       "text": "Harris School of Public Policy Studies",
#       "relevance": 0.101793,
#       "dbpedia_resource": "http://dbpedia.org/resource/Harris_School_of_Public_Policy_Studies"
#     },
#     {
#       "text": "Types of universities and colleges",
#       "relevance": 0.100115,
#       "dbpedia_resource": "http://dbpedia.org/resource/Types_of_universities_and_colleges"
#     },
#     {
#       "text": "Chicago Loop",
#       "relevance": 0.099964,
#       "dbpedia_resource": "http://dbpedia.org/resource/Chicago_Loop"
#     },
#     {
#       "text": "Graduate school",
#       "relevance": 0.09983,
#       "dbpedia_resource": "http://dbpedia.org/resource/Graduate_school"
#     },
#     {
#       "text": "Public university",
#       "relevance": 0.096932,
#       "dbpedia_resource": "http://dbpedia.org/resource/Public_university"
#     },
#     {
#       "text": "Milton Friedman",
#       "relevance": 0.095616,
#       "dbpedia_resource": "http://dbpedia.org/resource/Milton_Friedman"
#     },
#     {
#       "text": "Chicago Pile-1",
#       "relevance": 0.091666,
#       "dbpedia_resource": "http://dbpedia.org/resource/Chicago_Pile-1"
#     },
#     {
#       "text": "Midway Plaisance",
#       "relevance": 0.090659,
#       "dbpedia_resource": "http://dbpedia.org/resource/Midway_Plaisance"
#     },
#     {
#       "text": "Robert Zimmer",
#       "relevance": 0.090139,
#       "dbpedia_resource": "http://dbpedia.org/resource/Robert_Zimmer"
#     },
#     {
#       "text": "Chicago school",
#       "relevance": 0.089024,
#       "dbpedia_resource": "http://dbpedia.org/resource/Chicago_school_(sociology)"
#     },
#     {
#       "text": "Business school",
#       "relevance": 0.088215,
#       "dbpedia_resource": "http://dbpedia.org/resource/Business_school"
#     },
#     {
#       "text": "University of Chicago Medical Center",
#       "relevance": 0.088047,
#       "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago_Medical_Center"
#     },
#     {
#       "text": "President of the United States",
#       "relevance": 0.087933,
#       "dbpedia_resource": "http://dbpedia.org/resource/President_of_the_United_States"
#     },
#     {
#       "text": "Woodlawn, Chicago",
#       "relevance": 0.087463,
#       "dbpedia_resource": "http://dbpedia.org/resource/Woodlawn,_Chicago"
#     },
#     {
#       "text": "Hanna Holborn Gray",
#       "relevance": 0.087281,
#       "dbpedia_resource": "http://dbpedia.org/resource/Hanna_Holborn_Gray"
#     },
#     {
#       "text": "South Side",
#       "relevance": 0.086852,
#       "dbpedia_resource": "http://dbpedia.org/resource/South_Side_(Chicago)"
#     },
#     {
#       "text": "Committee on Institutional Cooperation",
#       "relevance": 0.086836,
#       "dbpedia_resource": "http://dbpedia.org/resource/Committee_on_Institutional_Cooperation"
#     },
#     {
#       "text": "Pritzker School of Medicine",
#       "relevance": 0.086698,
#       "dbpedia_resource": "http://dbpedia.org/resource/Pritzker_School_of_Medicine"
#     },
#     {
#       "text": "North Central Association of Colleges and Schools",
#       "relevance": 0.086555,
#       "dbpedia_resource": "http://dbpedia.org/resource/North_Central_Association_of_Colleges_and_Schools"
#     }
#   ],
#   "categories": [
#     {
#       "score": 0.969581,
#       "label": "/education/alumni and reunions"
#     },
#     {
#       "score": 0.89651,
#       "label": "/education/graduate school/college administration"
#     },
#     {
#       "score": 0.889065,
#       "label": "/education/graduate school/college"
#     }
#   ],
#   "warnings": [
#     "Text content exceeds 50000 character limit. Only first 50000 characters processed..."
#   ]
# }

# %% [markdown]
# ## Running Tweets through NLU

# %%
directory = '/home/jupyter/data/tweets/'
file = 'jeep_new.txt'
path = directory + file

# %%
tweets = pd.read_csv(path,sep='\t', names = ['id', 'lang', 'created_at', 'screen_name', \
                                                       'name', 'location', 'retweet_count', 'text'])

tweets = tweets[tweets['text'].str.contains("love|hate", case=False)==True]

tweets = tweets.sample(n=1000)

# %%
tweets.head(5)
# Out:
#                  id lang                      created_at      screen_name  \
# 11274  9.235088e+17   tl  Thu Oct 26 11:17:00 +0000 2017          jprlta_
# 46968  9.228689e+17   en  Tue Oct 24 16:54:28 +0000 2017   _________beast
# 32751  9.217452e+17   en  Sat Oct 21 14:29:04 +0000 2017     yendijackson
# 35505  9.218368e+17   en  Sat Oct 21 20:33:08 +0000 2017  joshhurleysnuts
# 14536  9.224361e+17   tl  Mon Oct 23 12:14:33 +0000 2017   josellevelasco
#
#                   name      location  retweet_count  \
# 11274                ♎          bp🐻🐼            0.0
# 46968            beast           NaN            0.0
# 32751     - yend🌴.  🇦🇬  New York, NY            0.0
# 35505               jh           NaN            0.0
# 14536  Joselle Velasco   Philippines            0.0
#
#                                                     text
# 11274  nakaisip ako bigla ng loveteam name kanina sa ...
# 46968  A royal pair. 📸: Victoria D. #jeep #itsajeepth...
# 32751  RT @YourTravelGroup: Such pretty views whilst ...
# 35505  @realDonaldTrump I jeep hearing about how you ...
# 14536  nakakita ng shs couple sa loob ng jeep na sina...

# %%
#Take a small sample
#tweets_eng = tweets[tweets['lang']=='en'].reset_index(drop=True).sample(frac=0.01, replace=True)
tweets_eng = tweets[tweets['lang']=='en'].reset_index(drop=True).head(10)

# %%
len(tweets_eng)
# Out:
# 10

# %%
# For NLU we DO NOT have to remove special characters to avoid problems with analysis
tweets_eng['text_clean'] = tweets_eng['text'].map(lambda x: re.sub('[^a-zA-Z0-9 @ . , : - _]', '', str(x)))

# %%
pd.set_option('display.max_colwidth', 200)
pd.set_option('display.max_rows', 10)
tweets_eng[['text']].head(5)
# Out:
#                                                                                                                                            text
# 0  A royal pair. 📸: Victoria D. #jeep #itsajeepthing #jeeplove #jeeplife #wrangler #jeepwrangler #jeepporn #jeepfamily… https://t.co/3gEXqREPic
# 1  RT @YourTravelGroup: Such pretty views whilst on the jeep safari 🚙 heading to #NelsonsDockyard ⛵ @antiguabarbuda #LoveAntiguaBarbuda https:…
# 2  @realDonaldTrump I jeep hearing about how you are fucking the middle amd lower class and the uneducated love it, go… https://t.co/3boAgJhYIo
# 3                                              Do your friends love Jeep as much as you do? Tag your off-roading buddy! https://t.co/svhbu7oE4X
# 4                                                                                 #JustForYouSweepstakes @sprint I would love to win the Jeep ☺

# %%
# Read individual columns
raw_id = tweets_eng["id"].values
raw_text = tweets_eng["text"].values

# %%
raw_text
# Out:
# array(['A royal pair. 📸: Victoria D. #jeep #itsajeepthing #jeeplove #jeeplife #wrangler #jeepwrangler #jeepporn #jeepfamily… https://t.co/3gEXqREPic',
#        'RT @YourTravelGroup: Such pretty views whilst on the jeep safari 🚙 heading to #NelsonsDockyard ⛵ @antiguabarbuda #LoveAntiguaBarbuda https:…',
#        '@realDonaldTrump I jeep hearing about how you are fucking the middle amd lower class and the uneducated love it, go… https://t.co/3boAgJhYIo',
#        'Do your friends love Jeep as much as you do? Tag your off-roading buddy! https://t.co/svhbu7oE4X',
#        '#JustForYouSweepstakes @sprint I would love to win the Jeep ☺',
#        'New design for Utah Lovers! #MokiDugway #Utah #SR261 #moab #roadtrip #4x4 #Jeep #mexicanhat #adventure #redrock #4wd https://t.co/6tu15dGkRT',
#        'A royal pair. 📸: Victoria D. #jeep #itsajeepthing #jeeplove #jeeplife #wrangler #jeepwrangler #jeepporn #jeepfamily… https://t.co/p2P4cvopFm',
#        '@eightyeightpark @eightyeightpark Love it! How long have you had your Jeep?',
#        '@fonzdelivers he drives a jeep, has a beard , trynna give some love , and he is the nicest nigga around',
#        'Rise and shine. #jeep #itsajeepthing #jeeplove #jeeplife #wrangler #jeepwrangler #jeepfamily #OIIIIIIIO https://t.co/R1yoieiLjL'],
#       dtype=object)

# %%
# Set up lists to collect sentiments, and scores
sentiment_list = []
score_list = []

# carry over existing values
tweet_id = []
tweet_list = []

# %%
count = 0
for raw_id, raw_text in \
zip(raw_id, raw_text):
    response = natural_language_understanding.analyze(
        language = "en", #do not NLU to guess language on Tweets
        text=raw_text,
        
            features = Features(
                        #entities = EntitiesOptions(sentiment = True, emotion = True),
                        #keywords = KeywordsOptions(sentiment = True, emotion = True),
                        #concepts = ConceptsOptions(limit = 50),
                        #relations = RelationsOptions(),
                        sentiment = SentimentOptions(),
                        #semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        #emotion = EmotionOptions(),
                        #categories = CategoriesOptions()
            )).get_result()

    if "label" in response["sentiment"]["document"]:
        sentiment_list.append(str(response["sentiment"]["document"]["label"]))
    else:
        sentiment_list.append("NA") 

    if "score" in response["sentiment"]["document"]:
        score_list.append(str(response["sentiment"]["document"]["score"]))
    else:
        score_list.append("0") 

    tweet_list.append(raw_text)
    tweet_id.append(raw_id)
    #print(count)
    #print(tweet_list)
    #print(tweet_id)
    count += 1

# %% [markdown]
# #### Dealing with nested JSONs

# %%
response
# Out:
# {'usage': {'text_units': 1, 'text_characters': 127, 'features': 1},
#  'sentiment': {'document': {'score': 0.514657, 'label': 'positive'}},
#  'language': 'en'}

# %%
response["sentiment"]
# Out:
# {'document': {'score': 0.514657, 'label': 'positive'}}

# %%
response["sentiment"]["document"]
# Out:
# {'score': 0.514657, 'label': 'positive'}

# %%
response["sentiment"]["document"]["label"]
# Out:
# 'positive'

# %%
response["sentiment"]["document"]["score"]
# Out:
# 0.514657

# %% [markdown]
# #### Combining results together

# %%
# Create a dataframe from the results
column_names = ["Tweet_Id", "Tweet_Text", "NLU_Sentiment", "NLU_Score"]
nlu_results = [tweet_id, tweet_list, sentiment_list, score_list]
results_dict = dict(zip(column_names,nlu_results))
results = pd.DataFrame.from_dict(results_dict, orient='columns')
results = results[column_names]   # set specific column order

# %%
results.head(10)
# Out:
#        Tweet_Id  \
# 0  9.228689e+17
# 1  9.217452e+17
# 2  9.218368e+17
# 3  9.236069e+17
# 4  9.226445e+17
# 5  9.225307e+17
# 6  9.225938e+17
# 7  9.236309e+17
# 8  9.228586e+17
# 9  9.228842e+17
#
#                                                                                                                                      Tweet_Text  \
# 0  A royal pair. 📸: Victoria D. #jeep #itsajeepthing #jeeplove #jeeplife #wrangler #jeepwrangler #jeepporn #jeepfamily… https://t.co/3gEXqREPic
# 1  RT @YourTravelGroup: Such pretty views whilst on the jeep safari 🚙 heading to #NelsonsDockyard ⛵ @antiguabarbuda #LoveAntiguaBarbuda https:…
# 2  @realDonaldTrump I jeep hearing about how you are fucking the middle amd lower class and the uneducated love it, go… https://t.co/3boAgJhYIo
# 3                                              Do your friends love Jeep as much as you do? Tag your off-roading buddy! https://t.co/svhbu7oE4X
# 4                                                                                 #JustForYouSweepstakes @sprint I would love to win the Jeep ☺
# 5  New design for Utah Lovers! #MokiDugway #Utah #SR261 #moab #roadtrip #4x4 #Jeep #mexicanhat #adventure #redrock #4wd https://t.co/6tu15dGkRT
# 6  A royal pair. 📸: Victoria D. #jeep #itsajeepthing #jeeplove #jeeplife #wrangler #jeepwrangler #jeepporn #jeepfamily… https://t.co/p2P4cvopFm
# 7                                                                   @eightyeightpark @eightyeightpark Love it! How long have you had your Jeep?
# 8                                       @fonzdelivers he drives a jeep, has a beard , trynna give some love , and he is the nicest nigga around
# 9               Rise and shine. #jeep #itsajeepthing #jeeplove #jeeplife #wrangler #jeepwrangler #jeepfamily #OIIIIIIIO https://t.co/R1yoieiLjL
#
#   NLU_Sentiment  NLU_Score
# 0       neutral          0
# 1      positive   0.628498
# 2      negative  -0.964076
# 3      positive   0.640436
# 4      positive   0.964391
# 5       neutral          0
# 6       neutral          0
# 7      positive   0.675406
# 8      positive   0.744969
# 9      positive   0.514657

# %%
# Data Export
outfile = "jeep_with_sentiment.xlsx"
outpath = directory + outfile

results.to_excel(outpath)

# %%
# !ls -l /home/jupyter/data/tweets/*.xlsx
# Out:
# -rw-r--r-- 1 root root 37889 Nov 28 17:23 /home/jupyter/data/tweets/jeep_adv_sentiment.xlsx
# -rw-r--r-- 1 root root  6495 Nov 29 17:29 /home/jupyter/data/tweets/jeep_with_sentiment.xlsx

# %%
import datetime
import pytz

datetime.datetime.now(pytz.timezone('US/Central')).strftime("%a, %d %B %Y %H:%M:%S")
# Out:
# 'Sun, 29 November 2020 11:29:42'
