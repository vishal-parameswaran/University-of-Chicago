# %% [markdown]
# ## NLP Class Assignment 5

# %%
import pandas as pd
import numpy as np
import os
import requests
import nltk as nltk
import nltk.corpus  
from nltk.text import Text
import pandas as pd
import re
import sys
import random
import spacy 
from spacy import displacy
from spacy.util import minibatch, compounding
from tqdm import tqdm
# spacy.prefer_gpu()
spacy.require_gpu()

print(spacy.__version__)
# Out:
# 3.5.2

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 500)

# %% [markdown]
# #### Read news data

# %%
news_path = 'https://storage.googleapis.com/msca-bdp-data-open/news/nlp_a_5_news.json'
news_df = pd.read_json(news_path, orient='records', lines=True)

print(f'Sample contains {news_df.shape[0]:,.0f} news articles')
news_df.head(2)
# Out:
# Sample contains 10,012 news articles
#                                                                                                                                                   url
# 0                                              http://kokomoperspective.com/obituaries/jon-w-horton/article_b6ba8e1e-cb9c-11eb-9868-fb11b88b9778.html  \
# 1  https://auto.economictimes.indiatimes.com/news/auto-components/birla-precision-to-ramp-up-capacity-to-tap-emerging-opportunities-in-india/81254902
#
#         date language
# 0 2021-06-13       en  \
# 1 2021-02-28       en
#
#                                                                                                  title
# 0                                                   Jon W. Horton | Obituaries | kokomoperspective.com  \
# 1       Birla Precision to ramp up capacity to tap emerging opportunities in India, Auto News, ET Auto
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   text
# 0  Jon W. Horton | Obituaries | kokomoperspective.comYou have permission to edit this article. EditCloseSign Up                        Log In                    Dashboard  LogoutMy Account Dashboard Profile Saved items LogoutCOVID-19Click here for the latest local news on COVID-19HomeAbout UsContact UsNewsLocalOpinionPoliticsNationalStateAgricultureLifestylesEngagements/Anniversaries/WeddingsAutosEntertainmentHealthHomesOutdoorsSportsNFLNCAAVitalsObituariesAutomotivee-EditionCouponsGalleries74°...
# 1      Birla Precision to ramp up capacity to tap emerging opportunities in India, Auto News, ET Auto     We have updated our terms and conditions and privacy policy Click "Continue" to accept and continue with ET AutoAccept the updated privacy & cookie policyDear user, ET Auto privacy and cookie policy has been updated to align with the new data regulations in European Union. Please review and accept these changes below to continue using the website.You can see our privacy policy & our cookie ...

# %% [markdown]
# #### Read Tweets data

# %%
tweets_path = 'https://storage.googleapis.com/msca-bdp-data-open/tweets/nlp_a_5_tweets.json'
tweets_df = pd.read_json(tweets_path, orient='records', lines=True)
print(f'Sample contains {tweets_df.shape[0]:,.0f} tweets')
tweets_df.head(2)
# Out:
# Sample contains 10,105 tweets
#                     id lang       date                  name retweeted
# 0  1534565117614084096   en 2022-06-08  Low Orbit Tourist 🌍📷            \
# 1  1534565743429394439   en 2022-06-08        CompleteCar.ie        RT
#
#                                                                                                                                                                                                                                                                                                                        text
# 0  Body &amp; Assembly - Halewood - United Kingdom\n🌍53.3504,-2.8352296,402m\n\nHalewood Body &amp; Assembly is a Jaguar Land Rover factory in Halewood, England, and forms the major part of the Halewood complex which is shared with Ford who manufacture transmissions at the site. [Wikipedia] https://t.co/LPmCnZIaVt
# 1                                                                                                                                                               Land Rover Ireland has announced that the new Range Rover Sport starts at €114,150, now on @completecar:\n\nhttps://t.co/TjGUkL3FYr https://t.co/QdVaEiJkjO

# %% [markdown]
# ## Using NLTK for NER on Tweets

# %%
tweets_df_nltk = tweets_df[['text']].copy()
news_df_nltk = news_df[['title','text']].copy()

# %%
tqdm.pandas()

# %%
def clean(string):
    url_pattern = r'(http|ftp|https):\/\/([\w_-]+(?:(?:\.[\w_-]+)+))([\w.,@?^=%&:\/~+#-]*[\w@?^=%&\/~+#-])'
    mention_pattern = r'[\s]*@[\w]+'
    hashtag_pattern = r'[\s]*#[\w]+'
    string_fixed = re.sub(url_pattern,"",string)
    string_fixed = re.sub(hashtag_pattern,"",string_fixed)
    string_fixed = re.sub(mention_pattern,"",string_fixed)
    string_fixed = string_fixed.replace('\n', '')
    tokens = string_fixed.split(" ")
    tokens = [word for word in tokens if len(word) > 1]
    tokens = [word for word in tokens if word.isalpha()]
    return(" ".join(tokens))

# %%
tweets_df_nltk['text'] = tweets_df_nltk['text'].progress_apply(clean)
# Out:
# 100%|██████████| 10105/10105 [00:00<00:00, 95738.30it/s]

# %%
def find_company_nltk(string):
    tokens = nltk.word_tokenize(string)    
    entities = []
    for chunk in nltk.ne_chunk(nltk.pos_tag(tokens), binary = False):
        if hasattr(chunk, 'label'):
            entity = ' '.join(c[0] for c in chunk)
            label = chunk.label()
            if label == 'ORGANIZATION':
                entities.append(entity)
    return(entities)

# %%
def find_company_by_sentences_nltk(string):
    entities = []
    for sent in nltk.sent_tokenize(string):
        for chunk in nltk.ne_chunk(nltk.pos_tag(nltk.word_tokenize(sent)), binary = False):
            if hasattr(chunk, 'label'):
                entity = ' '.join(c[0] for c in chunk)
                label = chunk.label()
                if label == 'ORGANIZATION':
                    entities.append(entity)
    return(entities)

# %%
tweets_df_nltk['companies'] = tweets_df_nltk['text'].progress_apply(find_company_nltk)
# Out:
# 100%|██████████| 10105/10105 [00:24<00:00, 416.00it/s]

# %%
tweets_df_nltk['companies_sentences'] = tweets_df_nltk['text'].progress_apply(find_company_by_sentences_nltk)
# Out:
# 100%|██████████| 10105/10105 [00:24<00:00, 415.01it/s]

# %% [markdown]
# Comparing the, per token and per sentence approach to NER

# %%
tweets_df_nltk[tweets_df_nltk['companies_sentences'].str.len() != 0][['companies','companies_sentences']].head(15)
# Out:
#                                                 companies
# 0                                              [Halewood]  \
# 4                                                  [Land]
# 10                                                [ROVER]
# 11                                                [TEKNO]
# 12                              [coversFull Service, ONO]
# 13         [performanceAutumn Pride, Land Rover Handicap]
# 15                         [Land Rover Discovery, Jaguar]
# 17                                               [ANYONE]
# 18                                   [Land Rover, CHUUMA]
# 20             [And Buick Top, RAM And Land Rover Finish]
# 21                                           [Land Rover]
# 22                                                  [UDA]
# 25                                             [Mercedes]
# 27  [ROVER, DISCOVERY Front Bumper Radiator Grille, eBay]
# 29                                                [ROVER]
#
#                                       companies_sentences
# 0                                              [Halewood]
# 4                                                  [Land]
# 10                                                [ROVER]
# 11                                                [TEKNO]
# 12                              [coversFull Service, ONO]
# 13         [performanceAutumn Pride, Land Rover Handicap]
# 15                         [Land Rover Discovery, Jaguar]
# 17                                               [ANYONE]
# 18                                   [Land Rover, CHUUMA]
# 20             [And Buick Top, RAM And Land Rover Finish]
# 21                                           [Land Rover]
# 22                                                  [UDA]
# 25                                             [Mercedes]
# 27  [ROVER, DISCOVERY Front Bumper Radiator Grille, eBay]
# 29                                                [ROVER]

# %% [markdown]
# ### Let us Find out the Most frequent companies with and without sentence segmentation

# %%
tweets_df_nltk['companies'].explode().value_counts().reset_index().head(20)
# Out:
#                           companies  count
# 0                        Land Rover    980
# 1                              Land    526
# 2                    General Motors    283
# 3                      Land Citroen    275
# 4                              eBay    233
# 5                              LAND    187
# 6                              Duke    162
# 7                           Duchess    145
# 8                             ROVER    142
# 9                       Jaguar Land    141
# 10                              SUV    112
# 11                            Rover    104
# 12                Jaguar Land Rover    103
# 13                        SHAMELESS     93
# 14                               UK     81
# 15             Land Rover Discovery     81
# 16  SHAMELESS Health Services Board     64
# 17                            Queen     63
# 18                 Clent Hills Vets     62
# 19                         Defender     58

# %%
tweets_df_nltk['companies_sentences'].explode().value_counts().reset_index().head(20)
# Out:
#                 companies_sentences  count
# 0                        Land Rover    980
# 1                              Land    526
# 2                    General Motors    283
# 3                      Land Citroen    275
# 4                              eBay    233
# 5                              LAND    187
# 6                              Duke    162
# 7                           Duchess    145
# 8                             ROVER    142
# 9                       Jaguar Land    141
# 10                              SUV    112
# 11                            Rover    104
# 12                Jaguar Land Rover    103
# 13                        SHAMELESS     93
# 14                               UK     81
# 15             Land Rover Discovery     81
# 16  SHAMELESS Health Services Board     64
# 17                            Queen     63
# 18                 Clent Hills Vets     62
# 19                         Defender     58

# %% [markdown]
# As we can see, the company we are discussing about is clearly Land Rover.

# %%
def company_filter(string):
    if len(string) >1 and 'Land Rover' in string or 'Jaguar Land Rover' in string:
        return string
    else:
        return pd.NA

# %% [markdown]
# ### Finding Companies that accompany the main company

# %%
tweets_df_nltk['companies_sentences'].apply(company_filter).dropna().explode().value_counts().reset_index().head(21)
# Out:
#     companies_sentences  count
# 0            Land Rover    395
# 1     Jaguar Land Rover    103
# 2      Clent Hills Vets     62
# 3               Duchess     40
# 4                  Duke     36
# 5              Defender     27
# 6                ZANUPF     23
# 7                    UK     18
# 8              Invictus     15
# 9                  GOLD     14
# 10             Sussexes     13
# 11                 Ford     12
# 12       Invictus Games     11
# 13                  WON     10
# 14                Queen      9
# 15              Jamaica      9
# 16                Hague      9
# 17        Prince Philip      8
# 18                 Land      8
# 19              MILLION      6
# 20  Forward Air Control      6

# %%
tweets_df_nltk['companies'].apply(company_filter).dropna().explode().value_counts().reset_index().head(21)
# Out:
#               companies  count
# 0            Land Rover    395
# 1     Jaguar Land Rover    103
# 2      Clent Hills Vets     62
# 3               Duchess     40
# 4                  Duke     36
# 5              Defender     27
# 6                ZANUPF     23
# 7                    UK     18
# 8              Invictus     15
# 9                  GOLD     14
# 10             Sussexes     13
# 11                 Ford     12
# 12       Invictus Games     11
# 13                  WON     10
# 14                Queen      9
# 15              Jamaica      9
# 16                Hague      9
# 17        Prince Philip      8
# 18                 Land      8
# 19              MILLION      6
# 20  Forward Air Control      6

# %% [markdown]
# We can see that ebay or BMW accompanies Land Rover the most.

# %%
def find_location_nltk(string):
    entities = []
    for chunk in nltk.ne_chunk(nltk.pos_tag(nltk.word_tokenize(string)), binary = False):
        if hasattr(chunk, 'label'):
            entity = ' '.join(c[0] for c in chunk)
            label = chunk.label()
            if label == 'GPE':
                entities.append(entity)
    return(entities)

# %%
def find_location_by_sentence_nltk(string):
    entities = []
    for sent in nltk.sent_tokenize(string):
        for chunk in nltk.ne_chunk(nltk.pos_tag(nltk.word_tokenize(sent)), binary = False):
            if hasattr(chunk, 'label'):
                entity = ' '.join(c[0] for c in chunk)
                label = chunk.label()
                if label == 'GPE':
                    entities.append(entity)
    return(entities)

# %%
tweets_df_nltk['locations'] = tweets_df_nltk['text'].progress_apply(find_location_nltk)
# Out:
# 100%|██████████| 10105/10105 [00:24<00:00, 414.78it/s]

# %%
tweets_df_nltk['locations_sentences'] = tweets_df_nltk['text'].progress_apply(find_location_by_sentence_nltk)
# Out:
# 100%|██████████| 10105/10105 [00:24<00:00, 413.98it/s]

# %%
tweets_df_nltk[(tweets_df_nltk['locations_sentences'].str.len() != 0) & (tweets_df_nltk['locations'].str.len() != 0) ][['locations','locations_sentences']].head(15)
# Out:
#             locations locations_sentences
# 1              [Land]              [Land]
# 2          [New Land]          [New Land]
# 9   [Russia, Bentley]   [Russia, Bentley]
# 10             [LAND]              [LAND]
# 13             [Fine]              [Fine]
# 19             [Land]              [Land]
# 20              [Kia]               [Kia]
# 25             [Land]              [Land]
# 26             [Land]              [Land]
# 27             [LAND]              [LAND]
# 28             [Land]              [Land]
# 29             [LAND]              [LAND]
# 30  [Cambridge, Once]   [Cambridge, Once]
# 31             [Land]              [Land]
# 32               [Un]                [Un]

# %% [markdown]
# As we can see, Land is confusing the nltk NER algorithm.

# %% [markdown]
# ## Using spacy for NER on Tweets

# %%
nlp = spacy.load("en_core_web_sm",exclude=['tok2vec','lemmatizer'])
nlp_senter = spacy.load("en_core_web_sm",exclude=['tok2vec','lemmatizer'])

# %%
nlp_senter.enable_pipe('senter')

# %%
nlp_senter.pipe_names
# Out:
# ['tagger', 'parser', 'senter', 'attribute_ruler', 'ner']

# %%
tweets_df_spacy = tweets_df[['text']].copy()
news_df_spacy = news_df[['title','text']].copy()

# %%
tweets_df_spacy['text'] = tweets_df_spacy['text'].progress_apply(clean)
# Out:
# 100%|██████████| 10105/10105 [00:00<00:00, 93276.91it/s]

# %%
title_entities = []
for doc in nlp.pipe(
    texts = tweets_df_spacy['text'],
):
    ents = []
    for ent in doc.ents:
        if ent.label_ in ['ORG']:
            ents.append(ent.text)
    title_entities.append(ents)

# %%
title_entities_senter = []
for doc in nlp_senter.pipe(
    texts = tweets_df_spacy['text'],
):
    ents = []
    for ent in doc.ents:
        if ent.label_ in ['ORG']:
            ents.append(ent.text)
    title_entities_senter.append(ents)

# %%
tweets_df_spacy['companies'] = title_entities
tweets_df_spacy['companies_sentences'] = title_entities_senter

# %%
tweets_df_spacy[tweets_df_spacy['companies_sentences'].str.len() != 0][['companies','companies_sentences']].head(15)
# Out:
#                                      companies
# 0                    [Jaguar Land Rover, Ford]  \
# 3                                     [Please]
# 4                                 [Land Rover]
# 5   [Land Rover, Mainstream Property Services]
# 6   [Land Rover, Mainstream Property Services]
# 7                           [Land Know, uache]
# 8                                 [Land Rover]
# 9                  [Land Lamborghini, Bentley]
# 10                                      [eBay]
# 11                                [Land Rover]
# 12                                       [ONO]
# 15                          [Mercedes, Jaguar]
# 17            [Rural Crime Report, Land Rover]
# 20                                  [Kia, RAM]
# 21    [Jaguar Land Rover Reports Retail Sales]
#
#                            companies_sentences
# 0                    [Jaguar Land Rover, Ford]
# 3                                     [Please]
# 4                                 [Land Rover]
# 5   [Land Rover, Mainstream Property Services]
# 6   [Land Rover, Mainstream Property Services]
# 7                           [Land Know, uache]
# 8                                 [Land Rover]
# 9                  [Land Lamborghini, Bentley]
# 10                                      [eBay]
# 11                                [Land Rover]
# 12                                       [ONO]
# 15                          [Mercedes, Jaguar]
# 17            [Rural Crime Report, Land Rover]
# 20                                  [Kia, RAM]
# 21    [Jaguar Land Rover Reports Retail Sales]

# %%
tweets_df_spacy['companies'].explode().value_counts().reset_index().head(20)
# Out:
#                                           companies  count
# 0                                        Land Rover    964
# 1                                 Jaguar Land Rover    549
# 2                                    General Motors    282
# 3                               Jaguar Land Citroen    277
# 4                                              eBay    248
# 5                                       Jaguar Land    144
# 6                                              Ford     90
# 7                                             Volvo     78
# 8                             the Jaguar Land Rover     77
# 9                                              Land     69
# 10                                           Jaguar     64
# 11                                      Paracetamol     64
# 12  the SHAMELESS Health Services Board of Zimbabwe     64
# 13                                        SHAMELESS     64
# 14                                            Rover     63
# 15                        Land Rover VRM EBL Please     62
# 16                             Nestle UKJaguar Land     47
# 17                                             Tata     46
# 18                                        Grenadier     45
# 19                                              BMW     43

# %%
tweets_df_spacy['companies_sentences'].explode().value_counts().reset_index().head(20)
# Out:
#                                 companies_sentences  count
# 0                                        Land Rover    964
# 1                                 Jaguar Land Rover    549
# 2                                    General Motors    282
# 3                               Jaguar Land Citroen    277
# 4                                              eBay    248
# 5                                       Jaguar Land    144
# 6                                              Ford     90
# 7                                             Volvo     78
# 8                             the Jaguar Land Rover     77
# 9                                              Land     69
# 10                                           Jaguar     64
# 11                                      Paracetamol     64
# 12  the SHAMELESS Health Services Board of Zimbabwe     64
# 13                                        SHAMELESS     64
# 14                                            Rover     63
# 15                        Land Rover VRM EBL Please     62
# 16                             Nestle UKJaguar Land     47
# 17                                             Tata     46
# 18                                        Grenadier     45
# 19                                              BMW     43

# %% [markdown]
# We can see that spacy also identifies land rover to be the company.

# %%
tweets_df_spacy['companies'].apply(company_filter).dropna().explode().value_counts().reset_index().head(21)
# Out:
#                        companies  count
# 0              Jaguar Land Rover    549
# 1                     Land Rover    351
# 2                          Volvo     58
# 3   Mainstream Property Services     40
# 4                  TEKNOOFFICIAL     34
# 5                           Ford     27
# 6                    Tata Motors     25
# 7                         Cayman     16
# 8                            JDF     16
# 9                         Nvidia     16
# 10            the Invictus Games     11
# 11                         Drive     11
# 12                        Jaguar     11
# 13   Engine Manufacturing Centre     10
# 14                           BMW     10
# 15                           JLR      9
# 16                   PA Observer      9
# 17                        NVIDIA      8
# 18                         Alexa      8
# 19                        Pramac      7
# 20                      HagueHis      7

# %% [markdown]
# The company that seems to appear the most along with Land Rover is Mainstream Property Services

# %%
title_entities = []
for doc in nlp.pipe(
    texts = tweets_df_spacy['text'],
):
    ents = []
    for ent in doc.ents:
        if ent.label_ in ['GPE']:
            ents.append(ent.text)
    title_entities.append(ents)

# %%
title_entities_senter = []
for doc in nlp_senter.pipe(
    texts = tweets_df_spacy['text'],
):
    ents = []
    for ent in doc.ents:
        if ent.label_ in ['GPE']:
            ents.append(ent.text)
    title_entities_senter.append(ents)

# %%
tweets_df_spacy['locations'] = title_entities
tweets_df_spacy['locations_sentences'] = title_entities_senter

# %%
tweets_df_spacy[(tweets_df_spacy['locations_sentences'].str.len() != 0) & (tweets_df_spacy['locations'].str.len() != 0) ][['locations','locations_sentences']].head(15)
# Out:
#                  locations    locations_sentences
# 3                     [UK]                   [UK]
# 9                 [Russia]               [Russia]
# 18                [CHUUMA]               [CHUUMA]
# 46                [Dublin]               [Dublin]
# 51   [india, india, india]  [india, india, india]
# 57                  [Land]                 [Land]
# 59                [UP, UP]               [UP, UP]
# 102        [Tucson, Skoda]        [Tucson, Skoda]
# 108                 [Rome]                 [Rome]
# 113          [REPLACEMENT]          [REPLACEMENT]
# 129              [Evoques]              [Evoques]
# 130               [Meghan]               [Meghan]
# 196            [Silverado]            [Silverado]
# 222              [Britain]              [Britain]
# 223                   [UK]                   [UK]

# %%
tweets_df_spacy['locations'].explode().value_counts().reset_index().head(20)
# Out:
#        locations  count
# 0             UK    175
# 1         Russia    108
# 2         Meghan     77
# 3          India     48
# 4           Land     39
# 5        Jamaica     35
# 6          China     24
# 7         London     23
# 8      Hollywood     23
# 9          Nyeri     23
# 10  South Africa     20
# 11        France     19
# 12     Cambridge     17
# 13        Kibaki     17
# 14    Zuiderpark     13
# 15            US     13
# 16         Aston     13
# 17       Regents     10
# 18     The Hague      9
# 19         Skoda      9

# %%
tweets_df_spacy['locations_sentences'].explode().value_counts().reset_index().head(20)
# Out:
#    locations_sentences  count
# 0                   UK    175
# 1               Russia    108
# 2               Meghan     77
# 3                India     48
# 4                 Land     39
# 5              Jamaica     35
# 6                China     24
# 7               London     23
# 8            Hollywood     23
# 9                Nyeri     23
# 10        South Africa     20
# 11              France     19
# 12           Cambridge     17
# 13              Kibaki     17
# 14          Zuiderpark     13
# 15                  US     13
# 16               Aston     13
# 17             Regents     10
# 18           The Hague      9
# 19               Skoda      9

# %% [markdown]
# As we can see, while the spacy algorithm does confuse a few names, with Locations, it is on average able, to find locations much better.

# %% [markdown]
# ### Thus for the Twitter Data the Spacy Algorithm is much better. There seems to be no difference between using a sentence segmenter.

# %% [markdown]
# ##### The Top 20 companies with the Spacy Algorithm and with no sentence segmenter.

# %%
tweets_df_spacy['companies'].explode().value_counts().reset_index().head(20)
# Out:
#                                           companies  count
# 0                                        Land Rover    964
# 1                                 Jaguar Land Rover    549
# 2                                    General Motors    282
# 3                               Jaguar Land Citroen    277
# 4                                              eBay    248
# 5                                       Jaguar Land    144
# 6                                              Ford     90
# 7                                             Volvo     78
# 8                             the Jaguar Land Rover     77
# 9                                              Land     69
# 10                                           Jaguar     64
# 11                                      Paracetamol     64
# 12  the SHAMELESS Health Services Board of Zimbabwe     64
# 13                                        SHAMELESS     64
# 14                                            Rover     63
# 15                        Land Rover VRM EBL Please     62
# 16                             Nestle UKJaguar Land     47
# 17                                             Tata     46
# 18                                        Grenadier     45
# 19                                              BMW     43

# %% [markdown]
# ##### The Top 20 locations with the Spacy Algorithm and with no sentence segmenter.

# %%
tweets_df_spacy['locations'].explode().value_counts().reset_index().head(20)
# Out:
#        locations  count
# 0             UK    175
# 1         Russia    108
# 2         Meghan     77
# 3          India     48
# 4           Land     39
# 5        Jamaica     35
# 6          China     24
# 7         London     23
# 8      Hollywood     23
# 9          Nyeri     23
# 10  South Africa     20
# 11        France     19
# 12     Cambridge     17
# 13        Kibaki     17
# 14    Zuiderpark     13
# 15            US     13
# 16         Aston     13
# 17       Regents     10
# 18     The Hague      9
# 19         Skoda      9

# %% [markdown]
# ## Using NLTK for NER on News

# %%
stopwords = set(nltk.corpus.stopwords.words('english'))
def remove_stop_words(string):
    words = string.split(" ")
    words = [x for x in words if x not in stopwords]
    return " ".join(words)

# %%
news_df_nltk['text'] = news_df_nltk['text'].progress_apply(clean)
news_df_nltk['text'] = news_df_nltk['text'].progress_apply(remove_stop_words)
# Out:
# 100%|██████████| 10012/10012 [00:06<00:00, 1563.50it/s]
# 100%|██████████| 10012/10012 [00:01<00:00, 5135.05it/s]

# %%
import polars as pl
news_df_nltk_pl = pl.from_pandas(news_df_nltk)

# %%
news_df_nltk_pl = news_df_nltk_pl.with_columns(
    (
        pl.col(["text"]).apply(find_company_nltk)
    ).alias("companies")
)

# %%
news_df_nltk_pl = news_df_nltk_pl.with_columns(
    (
        pl.col(["text"]).apply(find_company_by_sentences_nltk)
    ).alias("companies_sentences")
)

# %%
news_df_nltk_pl = news_df_nltk_pl.with_columns(
    (
        pl.col(["text"]).apply(find_location_nltk)
    ).alias("locations")
)

# %%
news_df_nltk_pl = news_df_nltk_pl.with_columns(
    (
        pl.col(["text"]).apply(find_location_by_sentence_nltk)
    ).alias("locations_sentences")
)

# %% [markdown]
# ### The top 20 Companies on the article

# %%
news_df_nltk_pl['companies'].explode().value_counts().sort(by=['counts'],descending=True).head(20)
# Out:
# shape: (20, 2)
# ┌─────────────────┬────────┐
# │ companies       ┆ counts │
# │ ---             ┆ ---    │
# │ str             ┆ u32    │
# ╞═════════════════╪════════╡
# │ MailOnline      ┆ 6865   │
# │ VERY            ┆ 4993   │
# │ NYC             ┆ 4383   │
# │ COVID           ┆ 3942   │
# │ …               ┆ …      │
# │ NOT             ┆ 1882   │
# │ UK              ┆ 1870   │
# │ DetailsExterior ┆ 1845   │
# │ US              ┆ 1839   │
# └─────────────────┴────────┘

# %%
news_df_nltk_pl['companies_sentences'].explode().value_counts().sort(by=['counts'],descending=True).head(20)
# Out:
# shape: (20, 2)
# ┌─────────────────────┬────────┐
# │ companies_sentences ┆ counts │
# │ ---                 ┆ ---    │
# │ str                 ┆ u32    │
# ╞═════════════════════╪════════╡
# │ MailOnline          ┆ 6865   │
# │ VERY                ┆ 4993   │
# │ NYC                 ┆ 4383   │
# │ COVID               ┆ 3942   │
# │ …                   ┆ …      │
# │ NOT                 ┆ 1882   │
# │ UK                  ┆ 1870   │
# │ DetailsExterior     ┆ 1845   │
# │ US                  ┆ 1839   │
# └─────────────────────┴────────┘

# %%
news_df_nltk_pd = news_df_nltk_pl.to_pandas()

# %%
def company_filter_news(string):
    if len(string) >1 and 'MailOnline' in string:
        return string
    else:
        return None

# %%
news_df_nltk_pd['companies'].apply(company_filter_news).dropna().explode().value_counts().reset_index().head(21)
# Out:
#                 companies  count
# 0              MailOnline   6865
# 1                     NYC   3848
# 2                    VERY   3655
# 3                   COVID   3263
# 4                      LA   2453
# 5                Princess   2001
# 6                     NOT   1527
# 7                     PDA   1464
# 8          Princess Diana   1387
# 9                MailMail   1351
# 10              PrintsOur   1351
# 11                  usHow   1351
# 12    CommentClearCloseDo   1345
# 13  MoneyMetroJobsiteMail   1343
# 14                    ALL   1325
# 15                   Mail   1322
# 16     complainLeadership   1309
# 17              UsTermsDo   1309
# 18         infoCA Privacy   1309
# 19         Comments Share   1246
# 20                     US   1231

# %%
news_df_nltk_pd['companies_sentences'].apply(company_filter_news).dropna().explode().value_counts().reset_index().head(21)
# Out:
#       companies_sentences  count
# 0              MailOnline   6865
# 1                     NYC   3848
# 2                    VERY   3655
# 3                   COVID   3263
# 4                      LA   2453
# 5                Princess   2001
# 6                     NOT   1527
# 7                     PDA   1464
# 8          Princess Diana   1387
# 9                MailMail   1351
# 10              PrintsOur   1351
# 11                  usHow   1351
# 12    CommentClearCloseDo   1345
# 13  MoneyMetroJobsiteMail   1343
# 14                    ALL   1325
# 15                   Mail   1322
# 16     complainLeadership   1309
# 17              UsTermsDo   1309
# 18         infoCA Privacy   1309
# 19         Comments Share   1246
# 20                     US   1231

# %%
news_df_nltk_pd['locations_sentences'].explode().value_counts().reset_index().head(20)
# Out:
#    locations_sentences  count
# 0          Los Angeles   7261
# 1             New York   5218
# 2        New York City   4989
# 3              British   4883
# 4                  New   3689
# 5               London   2968
# 6               Prince   2942
# 7             American   2773
# 8           Australian   2663
# 9                China   2197
# 10          California   2083
# 11              French   2074
# 12             Russian   1934
# 13             Britain   1702
# 14               India   1675
# 15           Australia   1648
# 16               Crown   1602
# 17              Amelia   1543
# 18               South   1536
# 19             Britney   1389

# %%
news_df_nltk_pd['locations'].explode().value_counts().reset_index().head(20)
# Out:
#         locations  count
# 0     Los Angeles   7261
# 1        New York   5218
# 2   New York City   4989
# 3         British   4883
# 4             New   3689
# 5          London   2968
# 6          Prince   2942
# 7        American   2773
# 8      Australian   2663
# 9           China   2197
# 10     California   2083
# 11         French   2074
# 12        Russian   1934
# 13        Britain   1702
# 14          India   1675
# 15      Australia   1648
# 16          Crown   1602
# 17         Amelia   1543
# 18          South   1536
# 19        Britney   1389

# %% [markdown]
# ## Using Spacy with News Text Data

# %%
spacy.require_cpu()
# Out:
# True

# %%
title_entities = []
for doc in nlp.pipe(
    texts = news_df_spacy['text'],
):
    ents = []
    for ent in doc.ents:
        if ent.label_ in ['ORG']:
            ents.append(ent.text)
    title_entities.append(ents)

# %%
news_df_spacy['companies'] = title_entities

# %%
news_df_spacy['companies'].explode().value_counts().reset_index().head(20)
# Out:
#          companies  count
# 0       MailOnline   8849
# 1         COVID-19   6373
# 2             Ford   5624
# 3           Toyota   5475
# 4          Hyundai   4333
# 5        Instagram   4010
# 6            Trump   3877
# 7            Honda   3786
# 8              BMW   3783
# 9           Amazon   3595
# 10         Netflix   3406
# 11          Palace   3214
# 12           COVID   3140
# 13              EV   2970
# 14  Britney Spears   2734
# 15           House   2437
# 16             BBC   2427
# 17          Nissan   2261
# 18            Duke   2226
# 19       Chevrolet   2096

# %% [markdown]
# We can see that spacy also identifies land rover to be the company.

# %%
news_df_spacy['companies'].apply(company_filter_news).dropna().explode().value_counts().reset_index().head(21)
# Out:
#          companies  count
# 0       MailOnline   8849
# 1        Instagram   3106
# 2            Trump   2982
# 3         COVID-19   2918
# 4          Netflix   2753
# 5            COVID   2662
# 6           Palace   2659
# 7           Amazon   2484
# 8   Britney Spears   2370
# 9            House   1967
# 10            Duke   1689
# 11    Paris Hilton   1520
# 12           Royal   1421
# 13           Crown   1418
# 14  the Daily Mail   1376
# 15     White House   1371
# 16           LACMA   1370
# 17        Facebook   1362
# 18       PrintsOur   1353
# 19  Privacy Policy   1345
# 20      Kanye West   1341

# %% [markdown]
# The company that seems to appear the most along with Land Rover is Mainstream Property Services

# %%
title_entities = []
for doc in nlp.pipe(
    texts = news_df_spacy['text'],
):
    ents = []
    for ent in doc.ents:
        if ent.label_ in ['GPE']:
            ents.append(ent.text)
    title_entities.append(ents)

# %%
news_df_spacy['locations'] = title_entities

# %%
news_df_spacy['locations'].explode().value_counts().reset_index().head(20)
# Out:
#          locations  count
# 0               LA  18382
# 1               UK  10682
# 2           London  10504
# 3      Los Angeles   9930
# 4               US   9855
# 5    New York City   7231
# 6        Hollywood   5907
# 7        Australia   5104
# 8            India   5016
# 9            Miami   4842
# 10          Meghan   4762
# 11        New York   4674
# 12  West Hollywood   4588
# 13      California   4403
# 14   Beverly Hills   4387
# 15          Sydney   4226
# 16         Britain   3910
# 17           China   3771
# 18          Malibu   3648
# 19            U.S.   3488

# %% [markdown]
# ## As we can see, the Spacy model is the best for the news text as well

# %% [markdown]
# ## Using NLTK for NER on News Titl

# %%
news_df_nltk['title'] = news_df_nltk['title'].progress_apply(clean)
# Out:
# 100%|██████████| 10012/10012 [00:00<00:00, 125109.85it/s]

# %%
news_df_nltk['companies_title'] = news_df_nltk['title'].progress_apply(find_company_nltk)
# Out:
# 100%|██████████| 10012/10012 [00:16<00:00, 589.07it/s]

# %%
news_df_nltk['companies_title_sentences'] = news_df_nltk['title'].progress_apply(find_company_by_sentences_nltk)
# Out:
# 100%|██████████| 10012/10012 [00:17<00:00, 578.33it/s]

# %% [markdown]
# ### The top 20 Companies on the article

# %%
news_df_nltk['companies_title'].explode().value_counts().reset_index().head(20)
# Out:
#         companies_title  count
# 0             Star News    170
# 1     Daily Mail Online    155
# 2       Shropshire Star     94
# 3       Automotive News     85
# 4                   BMW     79
# 5                  Ford     68
# 6                   RAM     53
# 7         Business Live     52
# 8                  SUVs     44
# 9             NewsBreak     43
# 10                Hindu     41
# 11                   UK     39
# 12           GMC Sierra     37
# 13  AutoSpies Auto News     35
# 14          News Driven     35
# 15          Ford Escape     34
# 16        Fast Lane Car     31
# 17         Express Star     31
# 18              CarWale     30
# 19                  SUV     30

# %%
news_df_nltk['companies_title_sentences'].explode().value_counts().reset_index().head(20)
# Out:
#    companies_title_sentences  count
# 0                  Star News    170
# 1          Daily Mail Online    155
# 2            Shropshire Star     94
# 3            Automotive News     85
# 4                        BMW     79
# 5                       Ford     68
# 6                        RAM     53
# 7              Business Live     52
# 8                       SUVs     44
# 9                  NewsBreak     43
# 10                     Hindu     41
# 11                        UK     39
# 12                GMC Sierra     37
# 13       AutoSpies Auto News     35
# 14               News Driven     35
# 15               Ford Escape     34
# 16             Fast Lane Car     31
# 17              Express Star     31
# 18                   CarWale     30
# 19                       SUV     30

# %%
def company_filter_news_title(string):
    if len(string) >1 and 'Star News' in string:
        return string
    else:
        return None

# %%
news_df_nltk['companies_title'].apply(company_filter_news_title).dropna().explode().value_counts().reset_index().head(21)
# Out:
#    companies_title  count
# 0        Star News     19
# 1       Canterbury      3
# 2     Christchurch      2
# 3        Addington      1
# 4              OCR      1
# 5             Bank      1
# 6               NZ      1
# 7        Emotional      1
# 8              ACC      1
# 9       Parliament      1
# 10           Josef      1
# 11           Delta      1
# 12          Devlin      1
# 13             NSW      1
# 14         Special      1
# 15          Strain      1
# 16        Hospital      1
# 17     Treacherous      1

# %%
news_df_nltk['companies_title_sentences'].apply(company_filter_news).dropna().explode().value_counts().reset_index().head(21)
# Out:
# Empty DataFrame
# Columns: [companies_title_sentences, count]
# Index: []

# %%
news_df_nltk['locations_title'] = news_df_nltk['title'].progress_apply(find_location_nltk)
# Out:
# 100%|██████████| 10012/10012 [00:17<00:00, 582.50it/s]

# %%
news_df_nltk['locations_sentences_title'] = news_df_nltk['title'].progress_apply(find_location_by_sentence_nltk)
# Out:
# 100%|██████████| 10012/10012 [00:17<00:00, 573.09it/s]

# %%
news_df_nltk['locations_sentences_title'].explode().value_counts().reset_index().head(20)
# Out:
#    locations_sentences_title  count
# 0                       Sale   1968
# 1                    Ontario   1183
# 2                   Manitoba    179
# 3                     Prince    177
# 4           British Columbia    160
# 5                        New    140
# 6                      North     99
# 7                    Alberta     95
# 8                      India     89
# 9                       Land     89
# 10                     China     86
# 11              Saskatchewan     62
# 12                    Quebec     34
# 13                     Daily     33
# 14                   British     33
# 15                Australian     33
# 16                 Australia     31
# 17                    Russia     31
# 18                      Nova     28
# 19                   Ukraine     25

# %%
news_df_nltk['locations_title'].explode().value_counts().reset_index().head(20)
# Out:
#      locations_title  count
# 0               Sale   1968
# 1            Ontario   1183
# 2           Manitoba    179
# 3             Prince    177
# 4   British Columbia    160
# 5                New    140
# 6              North     99
# 7            Alberta     95
# 8              India     89
# 9               Land     89
# 10             China     86
# 11      Saskatchewan     62
# 12            Quebec     34
# 13             Daily     33
# 14           British     33
# 15        Australian     33
# 16         Australia     31
# 17            Russia     31
# 18              Nova     28
# 19           Ukraine     25

# %% [markdown]
# ## Using Spacy with News Title Data

# %% [markdown]
# #### As we saw before. We do not have to use the senter, as it has a minimal impact on the output.

# %%
title_entities = []
for doc in nlp.pipe(
    texts = news_df_spacy['title'],
):
    ents = []
    for ent in doc.ents:
        if ent.label_ in ['ORG']:
            ents.append(ent.text)
    title_entities.append(ents)

# %%
news_df_spacy['companies_title'] = title_entities

# %%
news_df_spacy['companies_title'].explode().value_counts().reset_index().head(20)
# Out:
#                   companies_title  count
# 0                            Ford    270
# 1               Daily Mail Online    212
# 2                       Star News    209
# 3                         Hyundai    205
# 4                          Toyota    162
# 5                       Chevrolet    160
# 6                           Honda    146
# 7                 Shropshire Star    126
# 8                  Express & Star    120
# 9                 Automotive News    108
# 10                            BMW    107
# 11                            RAM     90
# 12  Otago Daily Times Online News     89
# 13                        ET Auto     76
# 14                      Auto News     74
# 15                             EV     72
# 16                Technology News     71
# 17                           Jeep     68
# 18                         Nissan     67
# 19                     Volkswagen     54

# %% [markdown]
# We can see that spacy also identifies land rover to be the company.

# %%
def company_filter_news_spacy(string):
    if len(string) >1 and 'Ford' in string:
        return string
    else:
        return None

# %%
news_df_spacy['companies_title'].apply(company_filter_news_spacy).dropna().explode().value_counts().reset_index().head(21)
# Out:
#                 companies_title  count
# 0                          Ford     78
# 1               Automotive News      6
# 2                            VW      5
# 3                            EV      5
# 4                          Audi      4
# 5                           NAV      4
# 6                            GM      3
# 7                   Local Trade      3
# 8              Specs & Features      3
# 9                           BMW      3
# 10                      Hyundai      2
# 11                     SuperCab      2
# 12                   Stellantis      2
# 13                  Nova Scotia      2
# 14  Escape SEL Specs & Features      2
# 15                        Apple      2
# 16                          XTR      2
# 17                         Fiat      2
# 18                         NAVI      1
# 19         Mercedes-Benz AMG SL      1
# 20                    Acura RDX      1

# %% [markdown]
# The company that seems to appear the most along with Land Rover is Mainstream Property Services

# %%
title_entities = []
for doc in nlp.pipe(
    texts = news_df_spacy['title'],
):
    ents = []
    for ent in doc.ents:
        if ent.label_ in ['GPE']:
            ents.append(ent.text)
    title_entities.append(ents)

# %%
news_df_spacy['locations_title'] = title_entities

# %%
news_df_spacy['locations_title'].explode().value_counts().reset_index().head(20)
# Out:
#      locations_title  count
# 0            Ontario   1316
# 1   British Columbia    198
# 2                 UK    194
# 3           Manitoba    181
# 4           Winnipeg    137
# 5              India    121
# 6            Toronto    118
# 7            Alberta    116
# 8             London    112
# 9          Cambridge     90
# 10                US     84
# 11      Saskatchewan     78
# 12        North York     72
# 13           Calgary     64
# 14              U.S.     63
# 15             China     59
# 16            Taiwan     54
# 17         Kitchener     45
# 18         Australia     44
# 19            Russia     43

# %% [markdown]
# # Thus as we can see for the title, The Spacy Library has the best methods
